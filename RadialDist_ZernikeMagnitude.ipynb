# %%
import pandas as pd
import numpy as np

# %%
# in Allcyto

RadialDistribution_ZernikeMagnitude = ['RadialDistribution_ZernikeMagnitude_CorrActin_0_0',
 'RadialDistribution_ZernikeMagnitude_CorrActin_1_1',
 'RadialDistribution_ZernikeMagnitude_CorrActin_2_0',
 'RadialDistribution_ZernikeMagnitude_CorrActin_2_2',
 'RadialDistribution_ZernikeMagnitude_CorrActin_3_1',
 'RadialDistribution_ZernikeMagnitude_CorrActin_3_3',
 'RadialDistribution_ZernikeMagnitude_CorrDNA2_0_0',
 'RadialDistribution_ZernikeMagnitude_CorrDNA2_1_1',
 'RadialDistribution_ZernikeMagnitude_CorrDNA2_2_0',
 'RadialDistribution_ZernikeMagnitude_CorrDNA2_2_2',
 'RadialDistribution_ZernikeMagnitude_CorrDNA2_3_1',
 'RadialDistribution_ZernikeMagnitude_CorrDNA2_3_3',
 'RadialDistribution_ZernikeMagnitude_CorrGolgi_0_0',
 'RadialDistribution_ZernikeMagnitude_CorrGolgi_1_1',
 'RadialDistribution_ZernikeMagnitude_CorrGolgi_2_0',
 'RadialDistribution_ZernikeMagnitude_CorrGolgi_2_2',
 'RadialDistribution_ZernikeMagnitude_CorrGolgi_3_1',
 'RadialDistribution_ZernikeMagnitude_CorrGolgi_3_3',
 'RadialDistribution_ZernikeMagnitude_CorrMito_0_0',
 'RadialDistribution_ZernikeMagnitude_CorrMito_1_1',
 'RadialDistribution_ZernikeMagnitude_CorrMito_2_0',
 'RadialDistribution_ZernikeMagnitude_CorrMito_2_2',
 'RadialDistribution_ZernikeMagnitude_CorrMito_3_1',
 'RadialDistribution_ZernikeMagnitude_CorrMito_3_3',
 'RadialDistribution_ZernikeMagnitude_CorrNileRed_0_0',
 'RadialDistribution_ZernikeMagnitude_CorrNileRed_1_1',
 'RadialDistribution_ZernikeMagnitude_CorrNileRed_2_0',
 'RadialDistribution_ZernikeMagnitude_CorrNileRed_2_2',
 'RadialDistribution_ZernikeMagnitude_CorrNileRed_3_1',
 'RadialDistribution_ZernikeMagnitude_CorrNileRed_3_3',
 'RadialDistribution_ZernikeMagnitude_CorrWGA_0_0',
 'RadialDistribution_ZernikeMagnitude_CorrWGA_1_1',
 'RadialDistribution_ZernikeMagnitude_CorrWGA_2_0',
 'RadialDistribution_ZernikeMagnitude_CorrWGA_2_2',
 'RadialDistribution_ZernikeMagnitude_CorrWGA_3_1',
 'RadialDistribution_ZernikeMagnitude_CorrWGA_3_3']

# %%
K1_194 = pd.read_csv('Datasets-selected/pam194ObjAllcyto.csv')

F1_195 = pd.read_csv('Datasets-selected/PAM195ObjAllcyto.csv')

K1_197 = pd.read_csv('Datasets-selected/PAM197ObjAllcyto.csv')

K2_198 = pd.read_csv('Datasets-selected/PAM198ObjAllcyto.csv')

K2_199 = pd.read_csv('Datasets-selected/pam199ObjAllcyto.csv')

F2_202 = pd.read_csv('Datasets-selected/PAM202ObjAllcyto.csv')

F2_203 = pd.read_csv('Datasets-selected/PAM203ObjAllcyto.csv')

# %%
# k1_197_dose = K1_197.groupby(by='Metadata_Metadata_Dose').mean()[RadialDistribution_ZernikeMagnitude]
# k1_197_dose = k1_197_dose.reset_index()
k1_197_info = pd.DataFrame(K1_197.describe())

# k1_194_dose = K1_194.groupby(by='Metadata_Metadata_Dose').mean()[RadialDistribution_ZernikeMagnitude]
# k1_194_dose = k1_194_dose.reset_index()
k1_194_info = pd.DataFrame(K1_194.describe())

# k2_198_dose = K2_198.groupby(by='Metadata_Metadata_Dose').mean()[RadialDistribution_ZernikeMagnitude]
# k2_198_dose = k2_198_dose.reset_index()
k2_198_info = pd.DataFrame(K2_198.describe())

# k2_199_dose = K2_199.groupby(by='Metadata_Metadata_Dose').mean()[RadialDistribution_ZernikeMagnitude]
# k2_199_dose = k2_199_dose.reset_index()
k2_199_info = pd.DataFrame(K2_199.describe())

# f1_195_dose = F1_195.groupby(by='Metadata_Metadata_Dose').mean()[RadialDistribution_ZernikeMagnitude]
# f1_195_dose = f1_195_dose.reset_index()
f1_195_info = pd.DataFrame(F1_195.describe())

# f2_202_dose = F2_202.groupby(by='Metadata_Metadata_Dose').mean()[RadialDistribution_ZernikeMagnitude]
# f2_202_dose = f2_202_dose.reset_index()
f2_202_info = pd.DataFrame(F2_202.describe())

# f2_203_dose = F2_203.groupby(by='Metadata_Metadata_Dose').mean()[RadialDistribution_ZernikeMagnitude]
# f2_203_dose = f2_203_dose.reset_index()
f2_203_info = pd.DataFrame(F2_203.describe())

# %%
import matplotlib.pyplot as plt

# %%
dna2 = ['RadialDistribution_ZernikeMagnitude_CorrDNA2_0_0',
       'RadialDistribution_ZernikeMagnitude_CorrDNA2_1_1',
       'RadialDistribution_ZernikeMagnitude_CorrDNA2_2_0',
       'RadialDistribution_ZernikeMagnitude_CorrDNA2_2_2',
       'RadialDistribution_ZernikeMagnitude_CorrDNA2_3_1',
       'RadialDistribution_ZernikeMagnitude_CorrDNA2_3_3']

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation='vertical')
plt.title('Mean of params considered in RadialDistribution_ZernikeMagnitude')
plt.plot(k1_194_info[dna2].loc['mean'], label = 'k1_194')
plt.plot(k1_197_info[dna2].loc['mean'], label = 'k1_197')
plt.plot(k2_198_info[dna2].loc['mean'], label = 'k2_198')
plt.plot(k2_199_info[dna2].loc['mean'], label = 'k2_199')
plt.plot(f1_195_info[dna2].loc['mean'], label = 'f1_195')
plt.plot(f2_202_info[dna2].loc['mean'], label = 'f2_202')
plt.plot(f2_203_info[dna2].loc['mean'], label = 'f2_203')
plt.legend(title='Parameter where:', framealpha=0.1, prop={'size': 8})
plt.xlabel("Params")
plt.ylabel("Scale")
# Out:
# Text(0, 0.5, 'Scale')

# %%
actin = ['RadialDistribution_ZernikeMagnitude_CorrActin_0_0',
       'RadialDistribution_ZernikeMagnitude_CorrActin_1_1',
       'RadialDistribution_ZernikeMagnitude_CorrActin_2_0',
       'RadialDistribution_ZernikeMagnitude_CorrActin_2_2',
       'RadialDistribution_ZernikeMagnitude_CorrActin_3_1',
       'RadialDistribution_ZernikeMagnitude_CorrActin_3_3']

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation='vertical')
plt.title('Mean of params considered in RadialDistribution_ZernikeMagnitude')
plt.plot(k1_194_info[actin].loc['mean'], label = 'k1_194')
plt.plot(k1_197_info[actin].loc['mean'], label = 'k1_197')
plt.plot(k2_198_info[actin].loc['mean'], label = 'k2_198')
plt.plot(k2_199_info[actin].loc['mean'], label = 'k2_199')
plt.plot(f1_195_info[actin].loc['mean'], label = 'f1_195')
plt.plot(f2_202_info[actin].loc['mean'], label = 'f2_202')
plt.plot(f2_203_info[actin].loc['mean'], label = 'f2_203')
plt.legend(title='Parameter where:', framealpha=0.1, prop={'size': 8})
plt.xlabel("Params")
plt.ylabel("Scale")
# Out:
# Text(0, 0.5, 'Scale')

# %%
golgi = ['RadialDistribution_ZernikeMagnitude_CorrGolgi_0_0',
 'RadialDistribution_ZernikeMagnitude_CorrGolgi_1_1',
 'RadialDistribution_ZernikeMagnitude_CorrGolgi_2_0',
 'RadialDistribution_ZernikeMagnitude_CorrGolgi_2_2',
 'RadialDistribution_ZernikeMagnitude_CorrGolgi_3_1',
 'RadialDistribution_ZernikeMagnitude_CorrGolgi_3_3']

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation='vertical')
plt.title('Mean of params considered in RadialDistribution_ZernikeMagnitude')
plt.plot(k1_194_info[golgi].loc['mean'], label = 'k1_194')
plt.plot(k1_197_info[golgi].loc['mean'], label = 'k1_197')
plt.plot(k2_198_info[golgi].loc['mean'], label = 'k2_198')
plt.plot(k2_199_info[golgi].loc['mean'], label = 'k2_199')
plt.plot(f1_195_info[golgi].loc['mean'], label = 'f1_195')
plt.plot(f2_202_info[golgi].loc['mean'], label = 'f2_202')
plt.plot(f2_203_info[golgi].loc['mean'], label = 'f2_203')
plt.legend(title='Parameter where:', framealpha=0.1, prop={'size': 8})
plt.xlabel("Params")
plt.ylabel("Scale")
# Out:
# Text(0, 0.5, 'Scale')

# %%
mito = ['RadialDistribution_ZernikeMagnitude_CorrMito_0_0',
 'RadialDistribution_ZernikeMagnitude_CorrMito_1_1',
 'RadialDistribution_ZernikeMagnitude_CorrMito_2_0',
 'RadialDistribution_ZernikeMagnitude_CorrMito_2_2',
 'RadialDistribution_ZernikeMagnitude_CorrMito_3_1',
 'RadialDistribution_ZernikeMagnitude_CorrMito_3_3']

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation='vertical')
plt.title('Mean of params considered in RadialDistribution_ZernikeMagnitude')
plt.plot(k1_194_info[mito].loc['mean'], label = 'k1_194')
plt.plot(k1_197_info[mito].loc['mean'], label = 'k1_197')
plt.plot(k2_198_info[mito].loc['mean'], label = 'k2_198')
plt.plot(k2_199_info[mito].loc['mean'], label = 'k2_199')
plt.plot(f1_195_info[mito].loc['mean'], label = 'f1_195')
plt.plot(f2_202_info[mito].loc['mean'], label = 'f2_202')
plt.plot(f2_203_info[mito].loc['mean'], label = 'f2_203')
plt.legend(title='Parameter where:', framealpha=0.1, prop={'size': 8})
plt.xlabel("Params")
plt.ylabel("Scale")
# Out:
# Text(0, 0.5, 'Scale')

# %%
nileRed = [ 'RadialDistribution_ZernikeMagnitude_CorrNileRed_0_0',
 'RadialDistribution_ZernikeMagnitude_CorrNileRed_1_1',
 'RadialDistribution_ZernikeMagnitude_CorrNileRed_2_0',
 'RadialDistribution_ZernikeMagnitude_CorrNileRed_2_2',
 'RadialDistribution_ZernikeMagnitude_CorrNileRed_3_1',
 'RadialDistribution_ZernikeMagnitude_CorrNileRed_3_3']

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation='vertical')
plt.title('Mean of params considered in RadialDistribution_ZernikeMagnitude')
plt.plot(k1_194_info[nileRed].loc['mean'], label = 'k1_194')
plt.plot(k1_197_info[nileRed].loc['mean'], label = 'k1_197')
plt.plot(k2_198_info[nileRed].loc['mean'], label = 'k2_198')
plt.plot(k2_199_info[nileRed].loc['mean'], label = 'k2_199')
plt.plot(f1_195_info[nileRed].loc['mean'], label = 'f1_195')
plt.plot(f2_202_info[nileRed].loc['mean'], label = 'f2_202')
plt.plot(f2_203_info[nileRed].loc['mean'], label = 'f2_203')
plt.legend(title='Parameter where:', framealpha=0.1, prop={'size': 8})
plt.xlabel("Params")
plt.ylabel("Scale")
# Out:
# Text(0, 0.5, 'Scale')

# %%
wga = ['RadialDistribution_ZernikeMagnitude_CorrWGA_0_0',
 'RadialDistribution_ZernikeMagnitude_CorrWGA_1_1',
 'RadialDistribution_ZernikeMagnitude_CorrWGA_2_0',
 'RadialDistribution_ZernikeMagnitude_CorrWGA_2_2',
 'RadialDistribution_ZernikeMagnitude_CorrWGA_3_1',
 'RadialDistribution_ZernikeMagnitude_CorrWGA_3_3']

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation='vertical')
plt.title('Mean of params considered in RadialDistribution_ZernikeMagnitude')
plt.plot(k1_194_info[wga].loc['mean'], label = 'k1_194')
plt.plot(k1_197_info[wga].loc['mean'], label = 'k1_197')
plt.plot(k2_198_info[wga].loc['mean'], label = 'k2_198')
plt.plot(k2_199_info[wga].loc['mean'], label = 'k2_199')
plt.plot(f1_195_info[wga].loc['mean'], label = 'f1_195')
plt.plot(f2_202_info[wga].loc['mean'], label = 'f2_202')
plt.plot(f2_203_info[wga].loc['mean'], label = 'f2_203')
plt.legend(title='Parameter where:', framealpha=0.1, prop={'size': 8})
plt.xlabel("Params")
plt.ylabel("Scale")
# Out:
# Text(0, 0.5, 'Scale')
