# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Data Ingestion
#
# #### As far as data ingestion goes, our sponsors only expect us to upload an experiment file locally. As per our meeting with them on 1/26, we'll be primarily processing two datasets: ObjCell (feature aggregate file), ObjNuclei (eveything the the nucleus) and ObjAllCyto (everything outside of the nucleus)
#
# #### For now, I'll be using the PAM194_Keratino_CytoPanel_1 experiment. If we come to an agreement with these preprocessing steps, then we can apply them to all experiments

# %%
# Ideally, user would specify an experiment to run pipeline on i.e. PAM194_Keratino_CytoPanel_1

# Experiment = (user input)
# file = ''

# Reading in the files locally for experiment PAM194_Keratino_CytoPanel_1
obj_cell = 'C:/Users/mdbla/Documents/UW-Capstone/PAM194_Keratino_CytoPanel_1/PAM194_Keratino_CytoPanel_1/pam194ObjCell.csv'
obj_nuclei = 'C:/Users/mdbla/Documents/UW-Capstone/PAM194_Keratino_CytoPanel_1/PAM194_Keratino_CytoPanel_1/pam194ObjNuclei.csv'
obj_cyto = 'C:/Users/mdbla/Documents/UW-Capstone/PAM194_Keratino_CytoPanel_1/PAM194_Keratino_CytoPanel_1/pam194ObjAllCyto.csv'

cell_data = pd.read_csv(obj_cell, sep = ',')
nuclei_data = pd.read_csv(obj_nuclei, sep = ',')
cyto_data = pd.read_csv(obj_cyto, sep = ',')

# %%
# looking at our datasets one by one

# dataset for ObjCell
cell_data.head()
# Out:
#    ImageNumber  ObjectNumber  Metadata_Date  Metadata_FileLocation  \
# 0            1             1            NaN                    NaN
# 1            1             2            NaN                    NaN
# 2            1             3            NaN                    NaN
# 3            1             4            NaN                    NaN
# 4            1             5            NaN                    NaN
#
#    Metadata_Frame Metadata_Metadata_Cytokine  Metadata_Metadata_Dose  \
# 0               0                       IFNg                      33
# 1               0                       IFNg                      33
# 2               0                       IFNg                      33
# 3               0                       IFNg                      33
# 4               0                       IFNg                      33
#
#   Metadata_Plate  Metadata_Run  Metadata_Series  ...  \
# 0        Plate 1           NaN                0  ...
# 1        Plate 1           NaN                0  ...
# 2        Plate 1           NaN                0  ...
# 3        Plate 1           NaN                0  ...
# 4        Plate 1           NaN                0  ...
#
#   Texture_Contrast_CorrMito_3_02_256 Texture_Contrast_CorrMito_3_03_256  \
# 0                         809.526316                        2213.948905
# 1                         140.515945                         297.913007
# 2                         416.107143                         637.340426
# 3                         369.692492                         442.252926
# 4                         422.836423                         480.798780
#
#   Texture_Contrast_CorrNileRed_3_00_256 Texture_Contrast_CorrNileRed_3_01_256  \
# 0                             63.312500                             62.456274
# 1                             41.003843                             44.320350
# 2                            131.801587                            141.045184
# 3                             58.827859                             72.721717
# 4                             44.629263                             90.982022
#
#   Texture_Contrast_CorrNileRed_3_02_256 Texture_Contrast_CorrNileRed_3_03_256  \
# 0                             43.161184                             64.916058
# 1                             41.900836                             55.248416
# 2                            123.582589                            184.291962
# 3                             56.393994                             68.367360
# 4                             79.689204                             90.452439
#
#   Texture_Contrast_CorrWGA_3_00_256 Texture_Contrast_CorrWGA_3_01_256  \
# 0                        456.894737                        558.148289
# 1                        423.985791                        488.225973
# 2                       1244.634921                       1873.365042
# 3                       1357.431873                       2371.832250
# 4                        645.309131                       1582.348315
#
#   Texture_Contrast_CorrWGA_3_02_256 Texture_Contrast_CorrWGA_3_03_256
# 0                        571.819079                        835.682482
# 1                        537.927107                        690.420186
# 2                       1386.792411                       1969.450355
# 3                       1386.081081                       1289.561769
# 4                       1484.908397                       2007.782927
#
# [5 rows x 123 columns]

# %%
# dataset for ObjNuclei
nuclei_data.head()
# Out:
#    ImageNumber  ObjectNumber  Metadata_Date  Metadata_FileLocation  \
# 0            1             1            NaN                    NaN
# 1            1             2            NaN                    NaN
# 2            1             3            NaN                    NaN
# 3            1             4            NaN                    NaN
# 4            1             5            NaN                    NaN
#
#    Metadata_Frame Metadata_Metadata_Cytokine  Metadata_Metadata_Dose  \
# 0               0                       IFNg                      33
# 1               0                       IFNg                      33
# 2               0                       IFNg                      33
# 3               0                       IFNg                      33
# 4               0                       IFNg                      33
#
#   Metadata_Plate  Metadata_Run  Metadata_Series  ...  \
# 0        Plate 1           NaN                0  ...
# 1        Plate 1           NaN                0  ...
# 2        Plate 1           NaN                0  ...
# 3        Plate 1           NaN                0  ...
# 4        Plate 1           NaN                0  ...
#
#                                       PathName_Actin  \
# 0  /Users/carolinestefani/Library/CloudStorage/Bo...
# 1  /Users/carolinestefani/Library/CloudStorage/Bo...
# 2  /Users/carolinestefani/Library/CloudStorage/Bo...
# 3  /Users/carolinestefani/Library/CloudStorage/Bo...
# 4  /Users/carolinestefani/Library/CloudStorage/Bo...
#
#                                         PathName_DNA  \
# 0  /Users/carolinestefani/Library/CloudStorage/Bo...
# 1  /Users/carolinestefani/Library/CloudStorage/Bo...
# 2  /Users/carolinestefani/Library/CloudStorage/Bo...
# 3  /Users/carolinestefani/Library/CloudStorage/Bo...
# 4  /Users/carolinestefani/Library/CloudStorage/Bo...
#
#                                        PathName_DNA2  \
# 0  /Users/carolinestefani/Library/CloudStorage/Bo...
# 1  /Users/carolinestefani/Library/CloudStorage/Bo...
# 2  /Users/carolinestefani/Library/CloudStorage/Bo...
# 3  /Users/carolinestefani/Library/CloudStorage/Bo...
# 4  /Users/carolinestefani/Library/CloudStorage/Bo...
#
#                                       PathName_Golgi  \
# 0  /Users/carolinestefani/Library/CloudStorage/Bo...
# 1  /Users/carolinestefani/Library/CloudStorage/Bo...
# 2  /Users/carolinestefani/Library/CloudStorage/Bo...
# 3  /Users/carolinestefani/Library/CloudStorage/Bo...
# 4  /Users/carolinestefani/Library/CloudStorage/Bo...
#
#                                        PathName_Mito  \
# 0  /Users/carolinestefani/Library/CloudStorage/Bo...
# 1  /Users/carolinestefani/Library/CloudStorage/Bo...
# 2  /Users/carolinestefani/Library/CloudStorage/Bo...
# 3  /Users/carolinestefani/Library/CloudStorage/Bo...
# 4  /Users/carolinestefani/Library/CloudStorage/Bo...
#
#                                     PathName_NileRed  \
# 0  /Users/carolinestefani/Library/CloudStorage/Bo...
# 1  /Users/carolinestefani/Library/CloudStorage/Bo...
# 2  /Users/carolinestefani/Library/CloudStorage/Bo...
# 3  /Users/carolinestefani/Library/CloudStorage/Bo...
# 4  /Users/carolinestefani/Library/CloudStorage/Bo...
#
#                                         PathName_WGA AreaShape_Area  \
# 0  /Users/carolinestefani/Library/CloudStorage/Bo...            133
# 1  /Users/carolinestefani/Library/CloudStorage/Bo...            126
# 2  /Users/carolinestefani/Library/CloudStorage/Bo...             91
# 3  /Users/carolinestefani/Library/CloudStorage/Bo...            150
# 4  /Users/carolinestefani/Library/CloudStorage/Bo...            196
#
#   AreaShape_Orientation Number_Object_Number
# 0             61.222325                    1
# 1             84.552142                    2
# 2             67.275934                    3
# 3            -18.041571                    4
# 4             75.615935                    5
#
# [5 rows x 28 columns]

# %%
# dataset for ObjAllcyto
cyto_data.head()
# Out:
#    ImageNumber  ObjectNumber  Metadata_Date  Metadata_FileLocation  \
# 0            1             1            NaN                    NaN
# 1            1             2            NaN                    NaN
# 2            1             3            NaN                    NaN
# 3            1             4            NaN                    NaN
# 4            1             5            NaN                    NaN
#
#    Metadata_Frame Metadata_Metadata_Cytokine  Metadata_Metadata_Dose  \
# 0               0                       IFNg                      33
# 1               0                       IFNg                      33
# 2               0                       IFNg                      33
# 3               0                       IFNg                      33
# 4               0                       IFNg                      33
#
#   Metadata_Plate  Metadata_Run  Metadata_Series  ...  \
# 0        Plate 1           NaN                0  ...
# 1        Plate 1           NaN                0  ...
# 2        Plate 1           NaN                0  ...
# 3        Plate 1           NaN                0  ...
# 4        Plate 1           NaN                0  ...
#
#   Texture_Contrast_CorrMito_3_02_256 Texture_Contrast_CorrMito_3_03_256  \
# 0                         797.291005                        2800.648649
# 1                         139.078833                         304.300176
# 2                         403.603175                         583.594488
# 3                         268.925081                         337.824499
# 4                         415.832206                         336.310726
#
#   Texture_Contrast_CorrNileRed_3_00_256 Texture_Contrast_CorrNileRed_3_01_256  \
# 0                             83.829016                             86.225806
# 1                             40.170459                             42.896766
# 2                            117.092822                            131.679842
# 3                             58.184106                             71.126437
# 4                             40.181446                             93.563662
#
#   Texture_Contrast_CorrNileRed_3_02_256 Texture_Contrast_CorrNileRed_3_03_256  \
# 0                             45.650794                             83.817568
# 1                             41.123471                             54.117129
# 2                            106.404151                            161.421260
# 3                             55.187622                             66.273639
# 4                             80.755074                             84.009464
#
#   Texture_Contrast_CorrWGA_3_00_256 Texture_Contrast_CorrWGA_3_01_256  \
# 0                        521.575130                        564.890323
# 1                        427.400479                        495.495029
# 2                       1337.491337                       1914.338603
# 3                       1030.760265                       1957.073276
# 4                        645.702592                       1900.503577
#
#   Texture_Contrast_CorrWGA_3_02_256 Texture_Contrast_CorrWGA_3_03_256
# 0                        403.862434                        818.189189
# 1                        543.160032                        702.931338
# 2                       1383.366300                       2127.477690
# 3                       1290.903583                        967.021490
# 4                       1764.224628                       2337.820189
#
# [5 rows x 157 columns]

# %% [markdown]
# # Dropping Unncessary Columns
#
# #### For data cleaning, we'll be removing columns that we've deemed unnecessary for our pipeline and NA values from our datasets

# %%
# This function serves to drop the columns that we've deemed unncessary for our pipeline
def drop_columns(data):
    data.drop(list(data.filter(regex = 'FileName_')), axis=1, inplace=True) # Dropping all of the columns starting with 'FileName_'
    data.drop(list(data.filter(regex = 'PathName_')), axis=1, inplace=True) # Dropping all of the columns starting with 'PathName_'
    data.drop(['Metadata_Date', 'Metadata_FileLocation', 'Metadata_Frame',
              'Metadata_Run', 'Metadata_Series'], axis=1, inplace=True)

# %%
drop_columns(cell_data)
drop_columns(nuclei_data)
drop_columns(cyto_data)

# %%
# Below a function that imputes these NAs for each measuremnt. For now, I'll use the mean, but let me 
# know if we should use another method for imputation such as KNN or MICE

def replace_NA(data):
    measurements = data.iloc[:,6:].columns # since we know which columns we're dropping, should this subset be fixed?
    for measure in measurements:
        if data[measure].isna().any():
            data[measure].fillna(data[measure].mean(), inplace=True)
            
print("The sum of NAs in the ObjCell dataset is:", cell_data.isna().sum().sum())
print("The sum of NAs in the ObjNuclei dataset is:", nuclei_data.isna().sum().sum())
print("The sume of NAs in the ObjALlCyto dataset is:", cyto_data.isna().sum().sum())
# Out:
# The sum of NAs in the ObjCell dataset is: 276
# The sum of NAs in the ObjNuclei dataset is: 0
# The sume of NAs in the ObjALlCyto dataset is: 414

# %%
replace_NA(cell_data)
replace_NA(nuclei_data)
replace_NA(cyto_data)

# %%
# looking at our cell data after dropping columns
cell_data.head()
# Out:
#    ImageNumber  ObjectNumber Metadata_Metadata_Cytokine  \
# 0            1             1                       IFNg
# 1            1             2                       IFNg
# 2            1             3                       IFNg
# 3            1             4                       IFNg
# 4            1             5                       IFNg
#
#    Metadata_Metadata_Dose Metadata_Plate Metadata_Well  AreaShape_Area  \
# 0                      33        Plate 1           B10           370.0
# 1                      33        Plate 1           B10          3152.0
# 2                      33        Plate 1           B10          1033.0
# 3                      33        Plate 1           B10          1978.0
# 4                      33        Plate 1           B10          1090.0
#
#    AreaShape_Orientation  Granularity_1_CorrActin  Granularity_1_CorrDNA2  \
# 0             -60.810939                32.776566               53.650428
# 1              49.398792                43.897883               73.654626
# 2              25.981245                42.339322               47.960220
# 3              61.618333                30.141310               30.521827
# 4              71.432709                39.343563               39.508533
#
#    ...  Texture_Contrast_CorrMito_3_02_256  \
# 0  ...                          809.526316
# 1  ...                          140.515945
# 2  ...                          416.107143
# 3  ...                          369.692492
# 4  ...                          422.836423
#
#    Texture_Contrast_CorrMito_3_03_256  Texture_Contrast_CorrNileRed_3_00_256  \
# 0                         2213.948905                              63.312500
# 1                          297.913007                              41.003843
# 2                          637.340426                             131.801587
# 3                          442.252926                              58.827859
# 4                          480.798780                              44.629263
#
#    Texture_Contrast_CorrNileRed_3_01_256  \
# 0                              62.456274
# 1                              44.320350
# 2                             141.045184
# 3                              72.721717
# 4                              90.982022
#
#    Texture_Contrast_CorrNileRed_3_02_256  \
# 0                              43.161184
# 1                              41.900836
# 2                             123.582589
# 3                              56.393994
# 4                              79.689204
#
#    Texture_Contrast_CorrNileRed_3_03_256  Texture_Contrast_CorrWGA_3_00_256  \
# 0                              64.916058                         456.894737
# 1                              55.248416                         423.985791
# 2                             184.291962                        1244.634921
# 3                              68.367360                        1357.431873
# 4                              90.452439                         645.309131
#
#    Texture_Contrast_CorrWGA_3_01_256  Texture_Contrast_CorrWGA_3_02_256  \
# 0                         558.148289                         571.819079
# 1                         488.225973                         537.927107
# 2                        1873.365042                        1386.792411
# 3                        2371.832250                        1386.081081
# 4                        1582.348315                        1484.908397
#
#    Texture_Contrast_CorrWGA_3_03_256
# 0                         835.682482
# 1                         690.420186
# 2                        1969.450355
# 3                        1289.561769
# 4                        2007.782927
#
# [5 rows x 104 columns]

# %% [markdown]
# #### IMPORTANT NOTE FOR TEAM: Below, you'll see that we have a 'Number_Object_Number' feature that is identical to the object number. I'll follow up with our sponsors to see what the difference is between the two and whether we should drop it.

# %%
# looking at our nuclei data after dropping columns
nuclei_data.head()
# Out:
#    ImageNumber  ObjectNumber Metadata_Metadata_Cytokine  \
# 0            1             1                       IFNg
# 1            1             2                       IFNg
# 2            1             3                       IFNg
# 3            1             4                       IFNg
# 4            1             5                       IFNg
#
#    Metadata_Metadata_Dose Metadata_Plate Metadata_Well  AreaShape_Area  \
# 0                      33        Plate 1           B10             133
# 1                      33        Plate 1           B10             126
# 2                      33        Plate 1           B10              91
# 3                      33        Plate 1           B10             150
# 4                      33        Plate 1           B10             196
#
#    AreaShape_Orientation  Number_Object_Number
# 0              61.222325                     1
# 1              84.552142                     2
# 2              67.275934                     3
# 3             -18.041571                     4
# 4              75.615935                     5

# %%
cyto_data.head()
# Out:
#    ImageNumber  ObjectNumber Metadata_Metadata_Cytokine  \
# 0            1             1                       IFNg
# 1            1             2                       IFNg
# 2            1             3                       IFNg
# 3            1             4                       IFNg
# 4            1             5                       IFNg
#
#    Metadata_Metadata_Dose Metadata_Plate Metadata_Well  \
# 0                      33        Plate 1           B10
# 1                      33        Plate 1           B10
# 2                      33        Plate 1           B10
# 3                      33        Plate 1           B10
# 4                      33        Plate 1           B10
#
#    Granularity_1_CorrActin  Granularity_1_CorrDNA2  Granularity_1_CorrGolgi  \
# 0                30.930115               21.388745                23.076034
# 1                43.908685               69.658228                24.140234
# 2                42.928617               36.212184                26.573823
# 3                30.272651               19.416316                27.274117
# 4                39.122643               18.667415                24.267978
#
#    Granularity_1_CorrMito  ...  Texture_Contrast_CorrMito_3_02_256  \
# 0               34.729626  ...                          797.291005
# 1               20.181313  ...                          139.078833
# 2               11.693345  ...                          403.603175
# 3               16.974175  ...                          268.925081
# 4               19.573362  ...                          415.832206
#
#    Texture_Contrast_CorrMito_3_03_256  Texture_Contrast_CorrNileRed_3_00_256  \
# 0                         2800.648649                              83.829016
# 1                          304.300176                              40.170459
# 2                          583.594488                             117.092822
# 3                          337.824499                              58.184106
# 4                          336.310726                              40.181446
#
#    Texture_Contrast_CorrNileRed_3_01_256  \
# 0                              86.225806
# 1                              42.896766
# 2                             131.679842
# 3                              71.126437
# 4                              93.563662
#
#    Texture_Contrast_CorrNileRed_3_02_256  \
# 0                              45.650794
# 1                              41.123471
# 2                             106.404151
# 3                              55.187622
# 4                              80.755074
#
#    Texture_Contrast_CorrNileRed_3_03_256  Texture_Contrast_CorrWGA_3_00_256  \
# 0                              83.817568                         521.575130
# 1                              54.117129                         427.400479
# 2                             161.421260                        1337.491337
# 3                              66.273639                        1030.760265
# 4                              84.009464                         645.702592
#
#    Texture_Contrast_CorrWGA_3_01_256  Texture_Contrast_CorrWGA_3_02_256  \
# 0                         564.890323                         403.862434
# 1                         495.495029                         543.160032
# 2                        1914.338603                        1383.366300
# 3                        1957.073276                        1290.903583
# 4                        1900.503577                        1764.224628
#
#    Texture_Contrast_CorrWGA_3_03_256
# 0                         818.189189
# 1                         702.931338
# 2                        2127.477690
# 3                         967.021490
# 4                        2337.820189
#
# [5 rows x 138 columns]

# %% [markdown]
# # Data Standardization
#
# #### Now we need to transform each dataset so that each feature has the same scale.
#
# #### IMPORTANT NOTE: Danish's PCA function handles the standardization, so we'll let his function handle it

# %% [markdown]
# # Outlier Removal
#
# #### Last step before PCA, we need to remove the outliers in our datasets.
#
# #### Because we standardized our data beforehand, we'll use the interquartile range to remove any outliers below 1QR and above 3QR of our features.
#
# #### IMPORTANT NOTE FOR TEAM: The below code does remove a large number of rows from our datasets. If you can review my function for improvements, I'd greatly appreciate it.

# %% [markdown]
# ## For Review
#
# ### Below is my attempt at removing our outliers using an IQR method. The problem I have is that it's removing too many outliers. If you run the cell below with whatever data that you use, you should get the number of outlers for each feature.

# %%
pd.options.mode.chained_assignment = None  # default='warn'
def replace_column_outliers(x):
    q1 = np.quantile(x, .25)
    q2 = np.quantile(x, .75)
    IQR = q2 - q1
    return pd.Series(np.where((x < (q1 - 1.5*IQR)) | (x > (q2+1.5*IQR)), float('nan'), x))

sub_df = cyto_data[cyto_data['Metadata_Metadata_Cytokine'] == 'IL9']
cyto_dose = sub_df[sub_df['Metadata_Metadata_Dose'] == 11]
features = cyto_dose.columns[6:]
print(cyto_dose[features].isnull().sum().sum())
for feature in features:
    cyto_dose[feature] = replace_column_outliers(cyto_dose[feature]).values

#replace_column_outliers(cyto_dose['Granularity_1_CorrActin'])

#print(test.shape)
#print(test2.shape)
print(cyto_data.shape)
for feature in features:
    print("Number of outliers for feature:", feature, "is ", cyto_dose[feature].isnull().sum())
# Out:
# 0
# (94370, 138)
# Number of outliers for feature: Granularity_1_CorrActin is  56
# Number of outliers for feature: Granularity_1_CorrDNA2 is  120
# Number of outliers for feature: Granularity_1_CorrGolgi is  50
# Number of outliers for feature: Granularity_1_CorrMito is  61
# Number of outliers for feature: Granularity_1_CorrNileRed is  59
# Number of outliers for feature: Granularity_1_CorrWGA is  120
# Number of outliers for feature: Granularity_2_CorrActin is  155
# Number of outliers for feature: Granularity_2_CorrDNA2 is  126
# Number of outliers for feature: Granularity_2_CorrGolgi is  162
# Number of outliers for feature: Granularity_2_CorrMito is  111
# Number of outliers for feature: Granularity_2_CorrNileRed is  116
# Number of outliers for feature: Granularity_2_CorrWGA is  131
# Number of outliers for feature: Granularity_3_CorrActin is  177
# Number of outliers for feature: Granularity_3_CorrDNA2 is  133
# Number of outliers for feature: Granularity_3_CorrGolgi is  92
# Number of outliers for feature: Granularity_3_CorrMito is  80
# Number of outliers for feature: Granularity_3_CorrNileRed is  140
# Number of outliers for feature: Granularity_3_CorrWGA is  74
# Number of outliers for feature: Granularity_4_CorrActin is  153
# Number of outliers for feature: Granularity_4_CorrDNA2 is  103
# Number of outliers for feature: Granularity_4_CorrGolgi is  98
# Number of outliers for feature: Granularity_4_CorrMito is  88
# Number of outliers for feature: Granularity_4_CorrNileRed is  114
# Number of outliers for feature: Granularity_4_CorrWGA is  122
# Number of outliers for feature: Intensity_MedianIntensity_CorrActin is  125
# Number of outliers for feature: Intensity_MedianIntensity_CorrDNA2 is  361
# Number of outliers for feature: Intensity_MedianIntensity_CorrGolgi is  76
# Number of outliers for feature: Intensity_MedianIntensity_CorrMito is  68
# Number of outliers for feature: Intensity_MedianIntensity_CorrNileRed is  133
# Number of outliers for feature: Intensity_MedianIntensity_CorrWGA is  160
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrActin_1of3 is  1
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrActin_2of3 is  663
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrActin_3of3 is  588
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrDNA2_1of3 is  1
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrDNA2_2of3 is  9
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrDNA2_3of3 is  41
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrGolgi_1of3 is  1
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrGolgi_2of3 is  658
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrGolgi_3of3 is  553
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrMito_1of3 is  1
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrMito_2of3 is  10
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrMito_3of3 is  402
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrNileRed_1of3 is  1
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrNileRed_2of3 is  660
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrNileRed_3of3 is  549
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrWGA_1of3 is  1
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrWGA_2of3 is  668
# Number of outliers for feature: RadialDistribution_MeanFrac_CorrWGA_3of3 is  613
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrActin_0_0 is  130
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrActin_1_1 is  116
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrActin_2_0 is  83
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrActin_2_2 is  85
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrActin_3_1 is  109
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrActin_3_3 is  139
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrDNA2_0_0 is  175
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrDNA2_1_1 is  135
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrDNA2_2_0 is  77
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrDNA2_2_2 is  136
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrDNA2_3_1 is  137
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrDNA2_3_3 is  187
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrGolgi_0_0 is  91
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrGolgi_1_1 is  138
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrGolgi_2_0 is  120
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrGolgi_2_2 is  113
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrGolgi_3_1 is  131
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrGolgi_3_3 is  169
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrMito_0_0 is  93
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrMito_1_1 is  92
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrMito_2_0 is  98
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrMito_2_2 is  105
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrMito_3_1 is  106
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrMito_3_3 is  136
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrNileRed_0_0 is  136
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrNileRed_1_1 is  133
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrNileRed_2_0 is  104
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrNileRed_2_2 is  111
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrNileRed_3_1 is  113
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrNileRed_3_3 is  173
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrWGA_0_0 is  172
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrWGA_1_1 is  135
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrWGA_2_0 is  94
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrWGA_2_2 is  126
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrWGA_3_1 is  120
# Number of outliers for feature: RadialDistribution_ZernikeMagnitude_CorrWGA_3_3 is  138
# Number of outliers for feature: Texture_AngularSecondMoment_CorrActin_3_00_256 is  348
# Number of outliers for feature: Texture_AngularSecondMoment_CorrActin_3_01_256 is  374
# Number of outliers for feature: Texture_AngularSecondMoment_CorrActin_3_02_256 is  343
# Number of outliers for feature: Texture_AngularSecondMoment_CorrActin_3_03_256 is  362
# Number of outliers for feature: Texture_AngularSecondMoment_CorrDNA2_3_00_256 is  45
# Number of outliers for feature: Texture_AngularSecondMoment_CorrDNA2_3_01_256 is  65
# Number of outliers for feature: Texture_AngularSecondMoment_CorrDNA2_3_02_256 is  38
# Number of outliers for feature: Texture_AngularSecondMoment_CorrDNA2_3_03_256 is  74
# Number of outliers for feature: Texture_AngularSecondMoment_CorrGolgi_3_00_256 is  315
# Number of outliers for feature: Texture_AngularSecondMoment_CorrGolgi_3_01_256 is  357
# Number of outliers for feature: Texture_AngularSecondMoment_CorrGolgi_3_02_256 is  311
# Number of outliers for feature: Texture_AngularSecondMoment_CorrGolgi_3_03_256 is  346
# Number of outliers for feature: Texture_AngularSecondMoment_CorrMito_3_00_256 is  304
# Number of outliers for feature: Texture_AngularSecondMoment_CorrMito_3_01_256 is  312
# Number of outliers for feature: Texture_AngularSecondMoment_CorrMito_3_02_256 is  316
# Number of outliers for feature: Texture_AngularSecondMoment_CorrMito_3_03_256 is  319
# Number of outliers for feature: Texture_AngularSecondMoment_CorrNileRed_3_00_256 is  331
# Number of outliers for feature: Texture_AngularSecondMoment_CorrNileRed_3_01_256 is  378
# Number of outliers for feature: Texture_AngularSecondMoment_CorrNileRed_3_02_256 is  338
# Number of outliers for feature: Texture_AngularSecondMoment_CorrNileRed_3_03_256 is  347
# Number of outliers for feature: Texture_AngularSecondMoment_CorrWGA_3_00_256 is  341
# Number of outliers for feature: Texture_AngularSecondMoment_CorrWGA_3_01_256 is  372
# Number of outliers for feature: Texture_AngularSecondMoment_CorrWGA_3_02_256 is  343
# Number of outliers for feature: Texture_AngularSecondMoment_CorrWGA_3_03_256 is  359
# Number of outliers for feature: Texture_Contrast_CorrActin_3_00_256 is  265
# Number of outliers for feature: Texture_Contrast_CorrActin_3_01_256 is  260
# Number of outliers for feature: Texture_Contrast_CorrActin_3_02_256 is  259
# Number of outliers for feature: Texture_Contrast_CorrActin_3_03_256 is  266
# Number of outliers for feature: Texture_Contrast_CorrDNA2_3_00_256 is  237
# Number of outliers for feature: Texture_Contrast_CorrDNA2_3_01_256 is  208
# Number of outliers for feature: Texture_Contrast_CorrDNA2_3_02_256 is  227
# Number of outliers for feature: Texture_Contrast_CorrDNA2_3_03_256 is  211
# Number of outliers for feature: Texture_Contrast_CorrGolgi_3_00_256 is  274
# Number of outliers for feature: Texture_Contrast_CorrGolgi_3_01_256 is  262
# Number of outliers for feature: Texture_Contrast_CorrGolgi_3_02_256 is  236
# Number of outliers for feature: Texture_Contrast_CorrGolgi_3_03_256 is  271
# Number of outliers for feature: Texture_Contrast_CorrMito_3_00_256 is  295
# Number of outliers for feature: Texture_Contrast_CorrMito_3_01_256 is  272
# Number of outliers for feature: Texture_Contrast_CorrMito_3_02_256 is  264
# Number of outliers for feature: Texture_Contrast_CorrMito_3_03_256 is  243
# Number of outliers for feature: Texture_Contrast_CorrNileRed_3_00_256 is  288
# Number of outliers for feature: Texture_Contrast_CorrNileRed_3_01_256 is  306
# Number of outliers for feature: Texture_Contrast_CorrNileRed_3_02_256 is  257
# Number of outliers for feature: Texture_Contrast_CorrNileRed_3_03_256 is  290
# Number of outliers for feature: Texture_Contrast_CorrWGA_3_00_256 is  263
# Number of outliers for feature: Texture_Contrast_CorrWGA_3_01_256 is  277
# Number of outliers for feature: Texture_Contrast_CorrWGA_3_02_256 is  232
# Number of outliers for feature: Texture_Contrast_CorrWGA_3_03_256 is  261

# %%
print(cyto_dose.shape)
print(cyto_dose.dropna().shape)
# Out:
# (3082, 138)
# (604, 138)

# %%
sub_df = cyto_data[cyto_data['Metadata_Metadata_Cytokine'] == 'IL9']
cyto_dose = sub_df[sub_df['Metadata_Metadata_Dose'] == 11]

def replace_column_outliers(x):
    q1 = np.quantile(x, .25)
    q2 = np.quantile(x, .75)
    IQR = q2 - q1
    return np.where((x < (q1 - 1.5*IQR)) | (x > (q2+1.5*IQR)), float('nan'), x)

test = pd.Series(replace_column_outliers(cyto_dose['Granularity_1_CorrActin']))

print(len(cyto_dose['Granularity_1_CorrActin']))
test.isnull().sum()
# Out:
# 3082
# 56

# %%
nuclei_data.head()
# Out:
#    ImageNumber  ObjectNumber Metadata_Metadata_Cytokine  \
# 0            1             1                       IFNg
# 1            1             2                       IFNg
# 2            1             3                       IFNg
# 3            1             4                       IFNg
# 4            1             5                       IFNg
#
#    Metadata_Metadata_Dose Metadata_Plate Metadata_Well  AreaShape_Area  \
# 0                      33        Plate 1           B10             133
# 1                      33        Plate 1           B10             126
# 2                      33        Plate 1           B10              91
# 3                      33        Plate 1           B10             150
# 4                      33        Plate 1           B10             196
#
#    AreaShape_Orientation  Number_Object_Number
# 0              61.222325                     1
# 1              84.552142                     2
# 2              67.275934                     3
# 3             -18.041571                     4
# 4              75.615935                     5

# %% [markdown]
# #### As you can see from above, A LOT of data was removed. May need to seek an alternative.
#
# #### I'll write our data to a clean folder from which we can conduct PCA and our analyses onto

# %%
# Ideally, this should write to a folder that'll serve as a temporary location for the PCA & Analysis scripts to read 
# from. We should discuss how to handle the hand-offs between our scripts

clean_cell.to_csv('C:/Users/mdbla/Documents/UW_VM_Capstone_2024/HTI/Preprocessed_Data/PAM194_ObjCell_clean.csv')
clean_nuclei.to_csv('C:/Users/mdbla/Documents/UW_VM_Capstone_2024/HTI/Preprocessed_Data/PAM194_ObjNuclei_clean.csv')
clean_cyto.to_csv('C:/Users/mdbla/Documents/UW_VM_Capstone_2024/HTI/Preprocessed_Data/PAM194_ObjCyto_clean.csv')
