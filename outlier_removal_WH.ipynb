# %%
import pandas as pd
import numpy as np
import sys
import warnings
warnings.filterwarnings('ignore')
from collections import Counter
from sklearn.preprocessing import MinMaxScaler
from src import stats_eda as eda

# %%
file = '../BRI/PAM194_Keratino_CytoPanel_1/pam194ObjCell.pkl'
df = pd.read_pickle(file)
features = df.columns[6:]

# %% [markdown]
# ### detect outliers by checking distributions performed between same experiments in different wells

# %%
from tqdm import tqdm

# %%
cdw = df.groupby(by=['Metadata_Metadata_Cytokine', 
                    'Metadata_Metadata_Dose',
                    'Metadata_Well']).mean().index

# n = 4
sds = [5,6]
idx_sd = {i:[] for i in sds}
idx_iqr = []
# running thru each pair of cytokine and dosage
for i in tqdm(cdw):
    c = i[0]
    d = i[1]
    w = i[2]
    # running thru every feature and find outliers
    for feature in features:
        # sub_df[feature] = replace_column_outliers(sub_df[feature]).values
        idx_sds = eda.replace_outliers_with_sd(df, feature, c, d, w, sds)
        for k, v in zip(idx_sds.keys(), idx_sds.values()):
            idx_sd[k] += v
            # idx_sd[k] = list(set(idx_sd[k]))
        idx_iqr += eda.replace_column_outliers(df, feature, c, d, w)
# Out:
# 100%|██████████| 66/66 [07:44<00:00,  7.04s/it]

# %%
# count the appearance of one row in across all the variables

idx_iqr_cnt = Counter(idx_iqr)

# %%
# count the appearance of one row in across all the variables

idx_sds_cnt = {}
for k, v in zip(idx_sd.keys(), idx_sd.values()):
    idx_sds_cnt[k] = Counter(v)
idx_sds_cnt
# Out:
# {5: Counter({27523: 1,
#           27636: 1,
#           27728: 1,
#           27921: 2,
#           28015: 1,
#           28101: 2,
#           28538: 1,
#           28838: 1,
#           27924: 3,
#           27536: 7,
#           27864: 43,
#           27965: 22,
#           28420: 2,
#           28496: 2,
#           28620: 11,
#           28672: 10,
#           27608: 8,
#           28012: 6,
#           28377: 1,
#           27916: 37,
#           27919: 31,
#           28021: 2,
#           28143: 1,
#           28445: 1,
#           28574: 2,
#           27640: 1,
#           27920: 1,
#           28790: 1,
#           28413: 4,
#           27567: 1,
#           28013: 3,
#           27635: 1,
#           27649: 1,
#           28016: 1,
#           27658: 1,
#           27559: 13,
#           27624: 21,
#           28507: 3,
#           28669: 6,
#           27518: 2,
#           27739: 1,
#           27746: 1,
#           27895: 1,
#           28008: 2,
#           28103: 1,
#           28237: 5,
#           28680: 3,
#           28754: 1,
#           28793: 1,
#           28826: 1,
#           27918: 11,
#           28487: 26,
#           28506: 6,
#           27513: 10,
#           28772: 11,
#           27774: 1,
#           27784: 3,
#           28417: 2,
#           28434: 10,
#           28605: 2,
#           28225: 1,
#           27841: 1,
#           28249: 1,
#           28261: 1,
#           28464: 2,
#           28648: 1,
#           28807: 1,
#           28273: 1,
#           28268: 1,
#           28356: 1,
#           28022: 1,
#           27577: 1,
#           27969: 2,
#           27733: 1,
#           27590: 5,
#           28135: 4,
#           28548: 8,
#           27493: 1,
#           27867: 2,
#           28159: 1,
#           27466: 4,
#           27601: 1,
#           27976: 4,
#           28066: 3,
#           28584: 2,
#           28638: 1,
#           28808: 3,
#           28478: 1,
#           27799: 1,
#           28462: 2,
#           28465: 2,
#           28617: 1,
#           28019: 5,
#           28360: 3,
#           27619: 1,
#           27941: 1,
#           27961: 1,
#           28173: 1,
#           27468: 2,
#           27479: 2,
#           27481: 2,
#           27533: 1,
#           27706: 1,
#           27925: 2,
#           27802: 2,
#           27826: 1,
#           27662: 1,
#           27707: 1,
#           28259: 4,
#           27670: 1,
#           28383: 1,
#           27598: 2,
#           28485: 1,
#           28692: 1,
#           27527: 1,
#           27568: 2,
#           28133: 2,
#           28515: 2,
#           28709: 1,
#           36152: 1,
#           36448: 1,
#           36596: 1,
#           36664: 1,
#           36816: 1,
#           36852: 1,
#           36918: 1,
#           37033: 1,
#           37265: 1,
#           36374: 1,
#           36472: 4,
#           36087: 2,
#           36131: 11,
#           36185: 4,
#           36192: 1,
#           36264: 11,
#           36709: 1,
#           36787: 2,
#           36990: 4,
#           35991: 1,
#           36590: 1,
#           36951: 25,
#           36240: 4,
#           35766: 16,
#           35773: 8,
#           35783: 8,
#           35785: 10,
#           35806: 1,
#           36080: 1,
#           36493: 1,
#           36790: 8,
#           36889: 10,
#           36917: 23,
#           36107: 1,
#           36110: 2,
#           36140: 1,
#           36432: 1,
#           36481: 1,
#           36938: 1,
#           36956: 1,
#           36969: 1,
#           37079: 1,
#           37170: 1,
#           36895: 1,
#           36177: 1,
#           36442: 1,
#           36904: 8,
#           36912: 15,
#           36916: 23,
#           37094: 3,
#           36708: 1,
#           36684: 1,
#           35918: 2,
#           36474: 26,
#           36962: 5,
#           37116: 13,
#           37290: 5,
#           35784: 1,
#           36000: 3,
#           36116: 1,
#           37031: 2,
#           35718: 11,
#           36480: 7,
#           35948: 2,
#           36583: 1,
#           37087: 2,
#           36067: 5,
#           36821: 7,
#           35895: 1,
#           35972: 1,
#           35999: 1,
#           36902: 1,
#           37240: 1,
#           35755: 1,
#           36161: 1,
#           35744: 2,
#           36746: 1,
#           35724: 1,
#           36658: 1,
#           36700: 1,
#           36818: 1,
#           37283: 1,
#           36626: 1,
#           36077: 1,
#           36102: 1,
#           36869: 5,
#           36898: 12,
#           36498: 4,
#           36721: 3,
#           36920: 4,
#           37267: 11,
#           36674: 9,
#           37275: 1,
#           36915: 2,
#           36229: 2,
#           35837: 1,
#           36865: 3,
#           37286: 2,
#           36762: 1,
#           35894: 1,
#           36100: 5,
#           35950: 1,
#           36435: 3,
#           36754: 4,
#           36758: 8,
#           36795: 1,
#           37019: 2,
#           35717: 3,
#           36592: 2,
#           37088: 2,
#           37291: 5,
#           36989: 1,
#           36260: 3,
#           36125: 1,
#           36238: 2,
#           36529: 3,
#           36757: 1,
#           36932: 1,
#           37037: 4,
#           37039: 2,
#           35829: 1,
#           35962: 4,
#           36071: 2,
#           35789: 2,
#           36431: 2,
#           36559: 4,
#           36749: 4,
#           35767: 3,
#           37076: 1,
#           37084: 3,
#           35815: 2,
#           37135: 7,
#           36160: 5,
#           36309: 3,
#           36317: 2,
#           35723: 1,
#           35731: 2,
#           35835: 1,
#           35852: 4,
#           36436: 2,
#           36755: 2,
#           35742: 4,
#           35909: 1,
#           35808: 1,
#           36193: 1,
#           36960: 1,
#           35745: 3,
#           35823: 2,
#           35915: 4,
#           35997: 3,
#           37156: 2,
#           36011: 3,
#           35985: 2,
#           36539: 3,
#           36104: 2,
#           36801: 1,
#           37028: 3,
#           37104: 1,
#           26173: 1,
#           26514: 1,
#           27002: 1,
#           27025: 1,
#           27363: 1,
#           26640: 2,
#           27047: 14,
#           27352: 21,
#           26175: 18,
#           26689: 5,
#           26779: 1,
#           26783: 31,
#           26786: 14,
#           26791: 4,
#           26865: 4,
#           26869: 4,
#           27091: 2,
#           27335: 4,
#           27383: 13,
#           27429: 1,
#           26375: 4,
#           27048: 4,
#           26761: 1,
#           26315: 1,
#           26781: 1,
#           27087: 2,
#           27348: 22,
#           27385: 2,
#           26961: 2,
#           26971: 1,
#           26638: 1,
#           26366: 1,
#           27138: 1,
#           27139: 1,
#           27262: 2,
#           26936: 1,
#           26915: 1,
#           26212: 1,
#           26447: 1,
#           26454: 1,
#           26596: 5,
#           26667: 1,
#           26680: 1,
#           26687: 1,
#           26949: 1,
#           27217: 1,
#           27334: 1,
#           27080: 2,
#           27074: 13,
#           27058: 5,
#           27256: 8,
#           27308: 1,
#           27040: 11,
#           27238: 3,
#           27442: 2,
#           26380: 7,
#           26410: 1,
#           26878: 1,
#           26879: 1,
#           26967: 1,
#           27084: 1,
#           26341: 1,
#           26518: 1,
#           26951: 2,
#           27208: 8,
#           26238: 3,
#           27102: 1,
#           27230: 1,
#           27179: 3,
#           27400: 2,
#           27367: 6,
#           26789: 4,
#           26301: 2,
#           26565: 2,
#           26811: 2,
#           26856: 2,
#           27039: 2,
#           27067: 2,
#           27401: 2,
#           26218: 4,
#           26608: 8,
#           26444: 5,
#           26273: 2,
#           26802: 3,
#           26943: 1,
#           27260: 3,
#           27397: 1,
#           26259: 3,
#           26303: 2,
#           27259: 2,
#           26633: 4,
#           26876: 2,
#           27382: 12,
#           26310: 9,
#           27064: 1,
#           26233: 3,
#           26492: 1,
#           26512: 3,
#           26946: 5,
#           26311: 1,
#           26327: 1,
#           26792: 2,
#           27387: 7,
#           27098: 1,
#           26632: 4,
#           26874: 4,
#           27096: 4,
#           26468: 2,
#           27182: 4,
#           27430: 2,
#           26820: 1,
#           34878: 1,
#           35138: 1,
#           35156: 1,
#           35253: 1,
#           35373: 1,
#           34505: 3,
#           34948: 20,
#           34989: 10,
#           35115: 15,
#           35404: 7,
#           35414: 16,
#           35528: 13,
#           34688: 18,
#           35163: 8,
#           34541: 1,
#           34920: 20,
#           35181: 1,
#           35184: 1,
#           35649: 16,
#           35437: 1,
#           35449: 6,
#           35455: 7,
#           35456: 8,
#           35458: 7,
#           35460: 9,
#           35465: 7,
#           35466: 10,
#           35468: 7,
#           35478: 6,
#           35520: 2,
#           35590: 1,
#           34766: 1,
#           34526: 2,
#           34549: 3,
#           35424: 1,
#           35428: 1,
#           34608: 1,
#           34613: 1,
#           34775: 1,
#           35037: 1,
#           35169: 1,
#           34656: 1,
#           34602: 8,
#           34607: 15,
#           34900: 5,
#           35396: 16,
#           35421: 1,
#           35596: 3,
#           34609: 11,
#           35714: 1,
#           34911: 5,
#           35349: 7,
#           34515: 6,
#           34523: 1,
#           34690: 1,
#           34638: 1,
#           34734: 1,
#           34548: 1,
#           34551: 4,
#           35621: 2,
#           35661: 1,
#           35131: 2,
#           34681: 1,
#           35246: 1,
#           35423: 1,
#           35620: 1,
#           34561: 2,
#           35038: 1,
#           34623: 1,
#           34545: 4,
#           35083: 1,
#           35688: 4,
#           34675: 1,
#           34718: 4,
#           34833: 3,
#           35474: 5,
#           34666: 6,
#           35388: 1,
#           35464: 4,
#           34809: 1,
#           35521: 9,
#           34684: 2,
#           34691: 7,
#           34790: 4,
#           34988: 8,
#           35418: 7,
#           34600: 2,
#           34629: 3,
#           34747: 1,
#           35296: 3,
#           35443: 2,
#           35505: 3,
#           34855: 1,
#           34597: 2,
#           35292: 2,
#           35271: 1,
#           35669: 5,
#           34612: 1,
#           34680: 3,
#           34725: 1,
#           34928: 2,
#           35251: 7,
#           35440: 2,
#           34510: 2,
#           34730: 2,
#           34939: 1,
#           34943: 1,
#           34584: 4,
#           34599: 2,
#           34778: 1,
#           34780: 4,
#           35198: 4,
#           35260: 3,
#           35608: 2,
#           34944: 1,
#           35335: 1,
#           34949: 2,
#           34837: 1,
#           25242: 1,
#           25389: 1,
#           25532: 1,
#           25569: 2,
#           25729: 1,
#           25772: 1,
#           25810: 1,
#           26053: 1,
#           24910: 4,
#           25223: 3,
#           25225: 6,
#           25239: 9,
#           25398: 4,
#           25802: 17,
#           25814: 1,
#           24972: 3,
#           25914: 19,
#           25758: 2,
#           25786: 1,
#           25974: 3,
#           26056: 5,
#           25020: 1,
#           25335: 1,
#           25457: 1,
#           25613: 3,
#           25785: 3,
#           25867: 1,
#           25889: 1,
#           24863: 1,
#           25563: 1,
#           25800: 1,
#           26002: 5,
#           24900: 1,
#           25819: 1,
#           24940: 3,
#           24978: 1,
#           24980: 1,
#           25268: 3,
#           25513: 1,
#           24875: 1,
#           24876: 1,
#           25226: 1,
#           24903: 1,
#           25776: 1,
#           25076: 3,
#           25312: 1,
#           25506: 11,
#           25614: 1,
#           26025: 11,
#           24726: 2,
#           24979: 5,
#           25070: 1,
#           25196: 5,
#           25624: 1,
#           25635: 9,
#           25698: 11,
#           25858: 2,
#           25900: 17,
#           26029: 1,
#           26096: 9,
#           26111: 14,
#           26126: 3,
#           26136: 3,
#           26161: 1,
#           25981: 5,
#           24792: 6,
#           25120: 3,
#           26036: 12,
#           25375: 3,
#           25684: 12,
#           24959: 4,
#           25466: 7,
#           24948: 2,
#           25968: 2,
#           24725: 1,
#           24798: 1,
#           24892: 2,
#           25056: 2,
#           25203: 1,
#           25972: 1,
#           26090: 1,
#           24877: 2,
#           25682: 1,
#           25519: 1,
#           25237: 1,
#           25637: 5,
#           25127: 1,
#           25508: 1,
#           24936: 13,
#           25174: 14,
#           25351: 4,
#           25511: 6,
#           25940: 7,
#           25952: 7,
#           25727: 8,
#           25032: 4,
#           25199: 3,
#           25487: 1,
#           25706: 9,
#           25855: 7,
#           25368: 5,
#           25593: 11,
#           24976: 12,
#           25067: 2,
#           25331: 2,
#           25374: 2,
#           24958: 4,
#           25138: 4,
#           25653: 2,
#           25953: 1,
#           25266: 1,
#           25551: 1,
#           25641: 3,
#           25689: 6,
#           25486: 1,
#           25879: 1,
#           25896: 1,
#           25468: 1,
#           24996: 2,
#           26146: 1,
#           24794: 1,
#           25822: 2,
#           25053: 5,
#           24743: 5,
#           24859: 1,
#           24767: 1,
#           25137: 1,
#           25333: 3,
#           25546: 2,
#           25579: 4,
#           25588: 4,
#           25999: 5,
#           25748: 3,
#           25754: 6,
#           26020: 1,
#           24759: 1,
#           24829: 1,
#           25321: 2,
#           25993: 3,
#           25866: 1,
#           25269: 2,
#           25824: 3,
#           25885: 1,
#           26007: 2,
#           26095: 4,
#           33651: 1,
#           33659: 1,
#           33737: 1,
#           33742: 1,
#           33749: 1,
#           33844: 2,
#           32972: 1,
#           33582: 25,
#           33082: 11,
#           33369: 4,
#           33402: 4,
#           33696: 2,
#           33960: 3,
#           34261: 13,
#           34265: 1,
#           34255: 3,
#           33192: 10,
#           33553: 6,
#           33596: 6,
#           34034: 1,
#           33422: 1,
#           33423: 1,
#           33692: 1,
#           33956: 1,
#           34062: 1,
#           34389: 1,
#           33579: 1,
#           34167: 1,
#           34267: 1,
#           33499: 1,
#           33918: 1,
#           33116: 2,
#           33148: 3,
#           33351: 2,
#           33750: 1,
#           33713: 1,
#           33957: 1,
#           33820: 2,
#           34354: 1,
#           33735: 15,
#           34324: 8,
#           32974: 4,
#           33223: 12,
#           33350: 1,
#           33452: 4,
#           33508: 1,
#           33566: 2,
#           33655: 1,
#           33840: 1,
#           34110: 7,
#           34112: 6,
#           34211: 14,
#           34280: 1,
#           34306: 9,
#           34330: 1,
#           33186: 1,
#           33407: 19,
#           33769: 1,
#           33031: 9,
#           34262: 1,
#           33740: 1,
#           34069: 1,
#           34278: 1,
#           34157: 8,
#           33194: 1,
#           33284: 1,
#           33388: 3,
#           33670: 1,
#           33702: 1,
#           34427: 1,
#           34472: 1,
#           33151: 2,
#           33888: 1,
#           33330: 1,
#           33953: 1,
#           34337: 1,
#           33789: 5,
#           33138: 1,
#           33166: 7,
#           33586: 8,
#           33682: 6,
#           34383: 2,
#           33793: 6,
#           33295: 3,
#           34451: 2,
#           33146: 1,
#           33442: 1,
#           33096: 3,
#           33238: 2,
#           33550: 1,
#           34080: 1,
#           33547: 2,
#           33695: 8,
#           33938: 1,
#           33943: 4,
#           33959: 10,
#           33996: 5,
#           34107: 3,
#           34198: 4,
#           33182: 2,
#           33440: 4,
#           33887: 2,
#           33356: 2,
#           34490: 6,
#           33354: 4,
#           33617: 3,
#           33989: 1,
#           34082: 2,
#           33454: 2,
#           33307: 1,
#           33412: 6,
#           33438: 6,
#           33981: 12,
#           33983: 3,
#           34327: 3,
#           33280: 5,
#           33260: 1,
#           33322: 4,
#           33721: 1,
#           34121: 4,
#           33015: 2,
#           33276: 1,
#           33315: 2,
#           34305: 3,
#           34355: 2,
#           33608: 3,
#           33331: 1,
#           33633: 1,
#           33717: 1,
#           33799: 1,
#           34374: 1,
#           33273: 2,
#           33288: 2,
#           34219: 4,
#           34234: 8,
#           33389: 2,
#           33786: 2,
#           33049: 1,
#           34369: 4,
#           34397: 1,
#           33650: 2,
#           34102: 3,
#           33619: 2,
#           33778: 2,
#           33779: 2,
#           33461: 1,
#           6217: 3,
#           6349: 1,
#           6355: 1,
#           6363: 1,
#           6462: 1,
#           7095: 1,
#           7435: 1,
#           6356: 1,
#           6925: 2,
#           6368: 1,
#           6949: 3,
#           6959: 6,
#           6962: 3,
#           6183: 3,
#           6184: 10,
#           6313: 2,
#           6398: 1,
#           6560: 2,
#           6663: 1,
#           6788: 8,
#           7092: 4,
#           7355: 29,
#           6327: 8,
#           6584: 8,
#           6202: 1,
#           6786: 1,
#           6787: 4,
#           7434: 1,
#           6353: 2,
#           6541: 3,
#           6556: 4,
#           6582: 4,
#           6607: 3,
#           6647: 9,
#           6649: 1,
#           6652: 11,
#           6656: 1,
#           6657: 5,
#           6659: 1,
#           6661: 5,
#           6914: 1,
#           6385: 1,
#           7189: 1,
#           6198: 1,
#           6319: 1,
#           6213: 10,
#           6482: 7,
#           6888: 1,
#           6921: 17,
#           7395: 4,
#           7018: 1,
#           7021: 1,
#           7215: 1,
#           7242: 1,
#           7442: 4,
#           6552: 8,
#           6253: 9,
#           6255: 7,
#           6264: 8,
#           6270: 9,
#           6277: 7,
#           6616: 10,
#           6633: 8,
#           6307: 4,
#           6176: 2,
#           6593: 3,
#           7383: 3,
#           6698: 1,
#           7093: 1,
#           6332: 1,
#           6352: 1,
#           6441: 1,
#           6710: 1,
#           7287: 2,
#           6229: 3,
#           6396: 2,
#           7372: 1,
#           6158: 1,
#           6248: 2,
#           6733: 1,
#           7086: 1,
#           6249: 6,
#           6257: 5,
#           6260: 7,
#           6268: 5,
#           6271: 7,
#           6272: 5,
#           6471: 7,
#           6486: 7,
#           6948: 3,
#           6950: 3,
#           6951: 4,
#           6956: 1,
#           6960: 4,
#           7246: 1,
#           7183: 1,
#           6306: 3,
#           6791: 1,
#           7014: 3,
#           7219: 1,
#           7353: 2,
#           6695: 8,
#           6800: 1,
#           7096: 1,
#           7400: 1,
#           7518: 2,
#           6196: 1,
#           6296: 3,
#           6565: 3,
#           6600: 1,
#           6426: 1,
#           6687: 1,
#           7231: 1,
#           7311: 2,
#           7525: 4,
#           7571: 3,
#           6256: 2,
#           6703: 2,
#           6820: 2,
#           7564: 1,
#           6212: 2,
#           6237: 3,
#           6239: 1,
#           7531: 1,
#           6192: 3,
#           6728: 5,
#           6805: 5,
#           6942: 5,
#           7338: 6,
#           7410: 4,
#           6860: 4,
#           6922: 1,
#           7078: 2,
#           7337: 1,
#           6427: 3,
#           6564: 2,
#           6994: 2,
#           6461: 1,
#           7047: 1,
#           7142: 5,
#           7412: 2,
#           7445: 1,
#           7561: 2,
#           6425: 1,
#           6933: 1,
#           7427: 1,
#           6283: 2,
#           6288: 2,
#           6318: 2,
#           6621: 1,
#           6467: 1,
#           6211: 1,
#           6870: 1,
#           7501: 2,
#           6472: 1,
#           6662: 1,
#           6290: 2,
#           6825: 2,
#           16824: 2,
#           16905: 1,
#           17140: 1,
#           17374: 1,
#           17475: 3,
#           17538: 1,
#           17561: 1,
#           16345: 23,
#           17013: 1,
#           17320: 9,
#           17606: 7,
#           16544: 12,
#           16646: 1,
#           16745: 27,
#           17212: 8,
#           17285: 26,
#           17509: 9,
#           16833: 1,
#           16508: 1,
#           16648: 9,
#           16871: 16,
#           17337: 1,
#           17373: 3,
#           17544: 5,
#           16218: 1,
#           16322: 2,
#           16887: 1,
#           17123: 1,
#           17433: 1,
#           17045: 1,
#           16399: 1,
#           16794: 1,
#           16978: 1,
#           16110: 15,
#           16273: 18,
#           16483: 2,
#           17471: 29,
#           16133: 1,
#           16423: 1,
#           16444: 2,
#           16756: 7,
#           16991: 3,
#           17109: 11,
#           17113: 2,
#           17121: 1,
#           ...}),
#  6: Counter({27523: 1,
#           27636: 1,
#           27728: 1,
#           28015: 1,
#           28538: 1,
#           27924: 3,
#           27536: 3,
#           27864: 42,
#           28496: 1,
#           28620: 8,
#           27919: 30,
#           27916: 30,
#           27920: 1,
#           28013: 1,
#           27635: 1,
#           27649: 1,
#           28101: 1,
#           27559: 10,
#           27624: 21,
#           27965: 19,
#           28507: 1,
#           27518: 1,
#           27895: 1,
#           28103: 1,
#           28680: 1,
#           28754: 1,
#           28793: 1,
#           27918: 8,
#           28487: 21,
#           28669: 3,
#           27513: 9,
#           28506: 3,
#           28772: 8,
#           27608: 2,
#           28434: 8,
#           27921: 1,
#           28648: 1,
#           28273: 1,
#           28268: 1,
#           27577: 1,
#           27733: 1,
#           28135: 3,
#           28413: 2,
#           28548: 6,
#           27466: 4,
#           28638: 1,
#           28808: 1,
#           27976: 2,
#           28462: 1,
#           28584: 1,
#           27590: 3,
#           28019: 1,
#           28360: 2,
#           27867: 1,
#           28672: 6,
#           27961: 1,
#           28012: 3,
#           27479: 2,
#           27925: 2,
#           28259: 4,
#           27670: 1,
#           28237: 2,
#           28485: 1,
#           28133: 1,
#           28515: 1,
#           36448: 1,
#           36918: 1,
#           36185: 2,
#           36264: 9,
#           36990: 3,
#           36493: 1,
#           36889: 7,
#           36107: 1,
#           36110: 2,
#           36432: 1,
#           36938: 1,
#           36956: 1,
#           36969: 1,
#           37079: 1,
#           37170: 1,
#           35766: 15,
#           35773: 5,
#           35783: 4,
#           35785: 8,
#           36904: 5,
#           36912: 10,
#           36916: 18,
#           36917: 19,
#           37094: 1,
#           36474: 22,
#           36951: 23,
#           36962: 4,
#           37116: 9,
#           36116: 1,
#           37290: 3,
#           35948: 1,
#           37087: 2,
#           35895: 1,
#           35972: 1,
#           36902: 1,
#           35755: 1,
#           35744: 2,
#           35724: 1,
#           36067: 1,
#           36821: 1,
#           36898: 7,
#           36131: 6,
#           36498: 2,
#           36920: 1,
#           36674: 5,
#           37267: 5,
#           36721: 1,
#           36762: 1,
#           36100: 5,
#           36480: 2,
#           36435: 2,
#           36758: 5,
#           35717: 3,
#           36592: 1,
#           37291: 3,
#           36260: 1,
#           36472: 1,
#           37037: 3,
#           36238: 1,
#           35718: 6,
#           36431: 1,
#           36559: 4,
#           36749: 4,
#           36754: 2,
#           35815: 1,
#           37135: 5,
#           35731: 2,
#           35852: 2,
#           36755: 1,
#           35742: 2,
#           35909: 1,
#           36317: 1,
#           36790: 5,
#           35745: 2,
#           35915: 4,
#           35997: 2,
#           37156: 2,
#           35823: 1,
#           36011: 2,
#           36160: 2,
#           36539: 3,
#           36869: 3,
#           35767: 2,
#           35962: 1,
#           37028: 3,
#           37084: 2,
#           36104: 1,
#           36309: 1,
#           27002: 1,
#           27363: 1,
#           27047: 10,
#           26175: 11,
#           26689: 4,
#           26783: 27,
#           26786: 7,
#           26791: 2,
#           26869: 3,
#           26375: 3,
#           27087: 1,
#           27348: 20,
#           27138: 1,
#           26454: 1,
#           26596: 4,
#           26667: 1,
#           26680: 1,
#           26949: 1,
#           27334: 1,
#           27080: 2,
#           27058: 5,
#           27308: 1,
#           27040: 7,
#           26341: 1,
#           26380: 5,
#           27208: 7,
#           26238: 1,
#           27102: 1,
#           27179: 2,
#           27074: 10,
#           27256: 4,
#           26565: 2,
#           26811: 2,
#           26856: 2,
#           27048: 2,
#           27067: 2,
#           27352: 18,
#           27401: 1,
#           26608: 7,
#           26218: 3,
#           26865: 1,
#           26273: 1,
#           26802: 1,
#           26943: 1,
#           26259: 2,
#           26303: 2,
#           27259: 1,
#           27260: 2,
#           26633: 3,
#           26444: 2,
#           27382: 10,
#           27383: 10,
#           26310: 5,
#           26492: 1,
#           26512: 3,
#           26327: 1,
#           27387: 3,
#           26789: 1,
#           26876: 1,
#           27098: 1,
#           26632: 4,
#           26874: 4,
#           27096: 4,
#           26233: 2,
#           26946: 4,
#           27182: 4,
#           27367: 2,
#           27430: 1,
#           34878: 1,
#           35138: 1,
#           35156: 1,
#           34948: 12,
#           34989: 8,
#           35115: 11,
#           35404: 3,
#           35414: 15,
#           34688: 12,
#           35528: 8,
#           34920: 12,
#           35181: 1,
#           35649: 7,
#           35437: 1,
#           35449: 6,
#           35455: 5,
#           35456: 4,
#           35458: 4,
#           35460: 9,
#           35465: 4,
#           35466: 9,
#           35468: 6,
#           35478: 6,
#           35520: 2,
#           34549: 2,
#           34775: 1,
#           34607: 9,
#           35421: 1,
#           35596: 2,
#           35396: 12,
#           34515: 6,
#           34734: 1,
#           34548: 1,
#           35621: 1,
#           35661: 1,
#           35131: 1,
#           34675: 1,
#           34718: 1,
#           34666: 1,
#           35464: 4,
#           35474: 4,
#           34833: 2,
#           35521: 3,
#           34684: 2,
#           34691: 5,
#           34790: 3,
#           34988: 5,
#           35163: 3,
#           34602: 6,
#           34609: 7,
#           34629: 3,
#           35296: 3,
#           35443: 1,
#           35505: 3,
#           34597: 1,
#           34911: 2,
#           34545: 1,
#           35349: 2,
#           35271: 1,
#           34680: 1,
#           34928: 2,
#           35251: 5,
#           34510: 1,
#           34730: 1,
#           35440: 1,
#           34778: 1,
#           34780: 4,
#           35198: 2,
#           34584: 2,
#           35260: 2,
#           35608: 2,
#           34900: 2,
#           34949: 2,
#           35418: 1,
#           35669: 4,
#           35688: 2,
#           25569: 1,
#           25810: 1,
#           26053: 1,
#           25802: 13,
#           25814: 1,
#           25225: 5,
#           25239: 6,
#           26056: 1,
#           25335: 1,
#           25785: 1,
#           24863: 1,
#           25800: 1,
#           26002: 4,
#           25613: 1,
#           24978: 1,
#           24980: 1,
#           24940: 1,
#           25268: 1,
#           24876: 1,
#           25312: 1,
#           26025: 8,
#           24726: 2,
#           25196: 3,
#           25624: 1,
#           25698: 6,
#           25900: 14,
#           26126: 1,
#           26161: 1,
#           25506: 9,
#           24792: 3,
#           25375: 2,
#           25635: 8,
#           24798: 1,
#           24892: 1,
#           25056: 2,
#           25972: 1,
#           25519: 1,
#           24972: 2,
#           25237: 1,
#           25466: 1,
#           24877: 1,
#           24959: 2,
#           25127: 1,
#           24936: 6,
#           25174: 3,
#           26096: 5,
#           25511: 2,
#           25940: 5,
#           25727: 6,
#           26111: 7,
#           25914: 12,
#           26136: 2,
#           25706: 7,
#           26036: 5,
#           25076: 1,
#           25368: 3,
#           25593: 10,
#           25067: 2,
#           25374: 2,
#           25855: 4,
#           24958: 3,
#           24976: 11,
#           25138: 2,
#           25653: 2,
#           25879: 1,
#           24996: 1,
#           25684: 8,
#           25822: 1,
#           25689: 2,
#           24979: 2,
#           25053: 3,
#           24859: 1,
#           25641: 1,
#           25579: 4,
#           25588: 4,
#           25999: 1,
#           25120: 2,
#           25333: 2,
#           25748: 2,
#           25754: 5,
#           24743: 2,
#           25546: 1,
#           25637: 2,
#           25993: 1,
#           25321: 1,
#           25824: 2,
#           25885: 1,
#           26095: 2,
#           25269: 1,
#           24910: 2,
#           33651: 1,
#           33659: 1,
#           33742: 1,
#           33844: 1,
#           33369: 3,
#           33696: 1,
#           33960: 1,
#           33402: 1,
#           33192: 8,
#           33553: 4,
#           34034: 1,
#           33423: 1,
#           33692: 1,
#           33956: 1,
#           34062: 1,
#           33116: 1,
#           33351: 2,
#           33713: 1,
#           34261: 9,
#           33223: 7,
#           33350: 1,
#           33452: 2,
#           33566: 1,
#           33655: 1,
#           34110: 4,
#           34112: 2,
#           34211: 10,
#           34280: 1,
#           34306: 9,
#           33735: 12,
#           34324: 4,
#           33407: 17,
#           34278: 1,
#           34157: 3,
#           33194: 1,
#           33284: 1,
#           33388: 3,
#           33670: 1,
#           33702: 1,
#           34472: 1,
#           33151: 1,
#           33166: 6,
#           33582: 17,
#           34383: 1,
#           33082: 4,
#           33789: 2,
#           34080: 1,
#           33148: 1,
#           33695: 7,
#           33943: 3,
#           33996: 5,
#           34107: 3,
#           34198: 3,
#           33182: 1,
#           33440: 3,
#           33596: 2,
#           33887: 2,
#           34490: 6,
#           33354: 3,
#           33586: 3,
#           32974: 2,
#           33238: 1,
#           33617: 2,
#           33412: 4,
#           33438: 5,
#           33959: 8,
#           33983: 1,
#           33356: 1,
#           33981: 9,
#           33322: 3,
#           33015: 1,
#           34305: 3,
#           34327: 2,
#           33031: 4,
#           33633: 1,
#           33717: 1,
#           33799: 1,
#           34121: 2,
#           34219: 2,
#           33389: 2,
#           34234: 7,
#           33786: 1,
#           33049: 1,
#           34369: 2,
#           33650: 1,
#           33619: 2,
#           33778: 2,
#           33779: 1,
#           33793: 2,
#           33461: 1,
#           6355: 1,
#           6363: 1,
#           6462: 1,
#           6183: 2,
#           6184: 8,
#           6560: 1,
#           6788: 5,
#           6787: 2,
#           6353: 2,
#           6541: 3,
#           6556: 3,
#           6582: 3,
#           6647: 8,
#           6649: 1,
#           6656: 1,
#           6657: 2,
#           6659: 1,
#           6661: 5,
#           7355: 23,
#           7395: 2,
#           7021: 1,
#           7215: 1,
#           7442: 1,
#           6921: 12,
#           6253: 9,
#           6270: 8,
#           6327: 4,
#           6584: 5,
#           6616: 6,
#           6633: 8,
#           6652: 9,
#           6213: 7,
#           6307: 4,
#           6552: 6,
#           6176: 1,
#           7287: 1,
#           6217: 1,
#           6158: 1,
#           6396: 1,
#           6593: 2,
#           7383: 1,
#           6229: 1,
#           6264: 7,
#           6249: 6,
#           6255: 5,
#           6260: 6,
#           6268: 5,
#           6271: 7,
#           6272: 5,
#           6277: 4,
#           6257: 2,
#           6471: 7,
#           6951: 4,
#           6959: 3,
#           6960: 3,
#           6948: 1,
#           6950: 1,
#           6482: 1,
#           6486: 5,
#           6791: 1,
#           7014: 3,
#           6695: 6,
#           7353: 1,
#           7400: 1,
#           7518: 2,
#           6296: 3,
#           6426: 1,
#           7311: 2,
#           7525: 3,
#           7571: 1,
#           6820: 2,
#           6239: 1,
#           6256: 1,
#           6703: 1,
#           6728: 5,
#           7410: 3,
#           6805: 3,
#           7412: 2,
#           6237: 1,
#           6288: 2,
#           6306: 2,
#           6607: 2,
#           6942: 3,
#           6925: 1,
#           6467: 1,
#           6283: 1,
#           6318: 1,
#           6565: 1,
#           6211: 1,
#           6860: 3,
#           7142: 3,
#           7501: 1,
#           6290: 2,
#           6427: 1,
#           6825: 2,
#           6564: 1,
#           16824: 2,
#           16905: 1,
#           17606: 4,
#           16745: 26,
#           17212: 4,
#           17285: 19,
#           16544: 9,
#           17337: 1,
#           16218: 1,
#           17123: 1,
#           16871: 10,
#           16648: 5,
#           17373: 2,
#           17433: 1,
#           17045: 1,
#           16399: 1,
#           16794: 1,
#           16110: 14,
#           16273: 15,
#           17544: 2,
#           16423: 1,
#           16756: 7,
#           17323: 1,
#           17446: 1,
#           17481: 10,
#           16418: 1,
#           17012: 1,
#           17318: 5,
#           17320: 5,
#           17039: 1,
#           17475: 1,
#           16146: 1,
#           16299: 1,
#           16681: 2,
#           16814: 2,
#           16469: 2,
#           16805: 19,
#           17021: 15,
#           17471: 25,
#           16986: 2,
#           17109: 8,
#           17415: 2,
#           16349: 9,
#           17113: 1,
#           16345: 15,
#           16770: 4,
#           16786: 1,
#           16788: 4,
#           16957: 2,
#           16973: 2,
#           17162: 7,
#           17136: 2,
#           16313: 1,
#           16436: 6,
#           17509: 6,
#           16271: 2,
#           17378: 4,
#           16958: 1,
#           16665: 2,
#           17371: 1,
#           16377: 4,
#           16438: 2,
#           16234: 6,
#           16342: 3,
#           16375: 6,
#           16822: 1,
#           17119: 1,
#           17295: 1,
#           16464: 3,
#           16719: 2,
#           17705: 2,
#           16329: 1,
#           16238: 2,
#           16725: 4,
#           17358: 2,
#           17260: 2,
#           16895: 1,
#           5118: 1,
#           5126: 1,
#           5339: 1,
#           5651: 1,
#           5926: 1,
#           4762: 6,
#           5526: 7,
#           5791: 1,
#           6081: 3,
#           6097: 1,
#           4753: 1,
#           5131: 1,
#           5138: 1,
#           5233: 1,
#           5535: 1,
#           4858: 1,
#           5075: 1,
#           5238: 1,
#           6021: 1,
#           5054: 1,
#           6082: 4,
#           4920: 1,
#           5891: 1,
#           5014: 9,
#           4564: 1,
#           4568: 1,
#           4659: 1,
#           4487: 6,
#           4879: 3,
#           5298: 6,
#           5766: 6,
#           4470: 2,
#           4624: 3,
#           4734: 3,
#           5244: 1,
#           4528: 2,
#           4532: 1,
#           4585: 1,
#           4669: 1,
#           5586: 1,
#           5919: 1,
#           4592: 1,
#           6127: 1,
#           4754: 1,
#           5175: 1,
#           5140: 1,
#           5366: 1,
#           4512: 16,
#           4967: 13,
#           5747: 3,
#           4857: 11,
#           5890: 1,
#           4749: 14,
#           4751: 10,
#           5077: 5,
#           5249: 5,
#           4533: 9,
#           4758: 7,
#           4808: 8,
#           5969: 5,
#           6136: 2,
#           5170: 3,
#           4577: 9,
#           5057: 2,
#           4521: 3,
#           4522: 2,
#           4854: 10,
#           4506: 2,
#           4494: 1,
#           4876: 1,
#           4591: 1,
#           5099: 5,
#           5892: 1,
#           4860: 4,
#           5078: 2,
#           5455: 1,
#           5353: 2,
#           5361: 1,
#           5833: 1,
#           4929: 1,
#           5109: 1,
#           5419: 7,
#           5875: 4,
#           4547: 4,
#           5288: 1,
#           6067: 1,
#           4843: 1,
#           5947: 3,
#           5623: 1,
#           4673: 2,
#           4891: 5,
#           5224: 2,
#           5789: 2,
#           5904: 2,
#           5923: 4,
#           5093: 1,
#           5367: 1,
#           4903: 2,
#           4925: 4,
#           5047: 2,
#           5279: 2,
#           5748: 1,
#           5511: 1,
#           5689: 2,
#           6137: 1,
#           14257: 1,
#           15604: 1,
#           15394: 2,
#           14366: 5,
#           14521: 10,
#           14962: 27,
#           15671: 12,
#           15706: 2,
#           15049: 8,
#           15066: 2,
#           15445: 1,
#           14222: 1,
#           14695: 1,
#           14762: 1,
#           14765: 1,
#           14767: 1,
#           14936: 4,
#           14938: 1,
#           14942: 1,
#           15622: 1,
#           14809: 2,
#           14810: 2,
#           15333: 3,
#           14778: 1,
#           16093: 1,
#           15399: 1,
#           14133: 2,
#           14756: 3,
#           15047: 1,
#           15586: 2,
#           16065: 1,
#           14858: 6,
#           14805: 1,
#           15391: 1,
#           14149: 6,
#           15224: 13,
#           15022: 1,
#           15730: 3,
#           14586: 2,
#           16107: 2,
#           16108: 2,
#           14937: 1,
#           15031: 1,
#           14932: 3,
#           15118: 1,
#           15316: 1,
#           14453: 2,
#           15673: 2,
#           14500: 1,
#           15063: 1,
#           16056: 9,
#           14421: 10,
#           14961: 16,
#           14787: 4,
#           14795: 4,
#           14973: 3,
#           14631: 3,
#           14171: 1,
#           15233: 5,
#           15296: 1,
#           15438: 2,
#           15553: 3,
#           15567: 2,
#           14885: 3,
#           14905: 5,
#           15294: 4,
#           15070: 2,
#           14465: 1,
#           15573: 1,
#           14394: 3,
#           14761: 3,
#           16017: 3,
#           14929: 1,
#           16106: 2,
#           14440: 1,
#           14163: 1,
#           14172: 1,
#           14654: 3,
#           14896: 2,
#           14908: 5,
#           14970: 3,
#           14993: 5,
#           15170: 4,
#           15173: 3,
#           14552: 4,
#           14509: 2,
#           14377: 1,
#           15454: 2,
#           14364: 3,
#           15340: 1,
#           15652: 4,
#           15458: 1,
#           14138: 1,
#           14238: 4,
#           14517: 2,
#           14997: 1,
#           15490: 3,
#           16012: 4,
#           16013: 2,
#           16010: 2,
#           15238: 2,
#           14182: 1,
#           14254: 4,
#           14272: 1,
#           14368: 3,
#           14401: 4,
#           14622: 2,
#           15504: 1,
#           15526: 1,
#           14475: 2,
#           14554: 2,
#           14974: 1,
#           15634: 1,
#           15636: 2,
#           3237: 1,
#           3351: 1,
#           3595: 1,
#           3609: 4,
#           3964: 1,
#           4268: 5,
#           3165: 2,
#           3337: 1,
#           3430: 4,
#           3851: 8,
#           4039: 2,
#           4162: 1,
#           3418: 2,
#           3711: 1,
#           3888: 1,
#           3897: 1,
#           3288: 5,
#           4256: 13,
#           3209: 2,
#           4257: 1,
#           3193: 1,
#           3383: 1,
#           3499: 1,
#           3959: 10,
#           4151: 12,
#           4298: 11,
#           3446: 3,
#           3541: 4,
#           3709: 2,
#           3970: 2,
#           3575: 1,
#           3587: 2,
#           4344: 1,
#           3173: 1,
#           3264: 6,
#           4082: 1,
#           3216: 8,
#           3968: 1,
#           4260: 1,
#           3653: 3,
#           3733: 1,
#           3767: 1,
#           3549: 2,
#           3218: 2,
#           4446: 2,
#           3349: 5,
#           3466: 2,
#           3729: 2,
#           4174: 3,
#           4189: 3,
#           3192: 2,
#           3673: 1,
#           4136: 6,
#           3348: 3,
#           3427: 8,
#           4403: 8,
#           3526: 5,
#           3161: 1,
#           3451: 1,
#           3148: 1,
#           3376: 1,
#           3159: 3,
#           3586: 3,
#           3858: 2,
#           3880: 4,
#           4270: 4,
#           4165: 2,
#           3725: 1,
#           4014: 2,
#           3447: 1,
#           3976: 2,
#           3696: 2,
#           4296: 1,
#           12738: 1,
#           13455: 1,
#           13831: 1,
#           13999: 1,
#           12706: 5,
#           12875: 4,
#           13127: 6,
#           13714: 1,
#           13727: 9,
#           13902: 6,
#           13147: 1,
#           13951: 1,
#           13952: 1,
#           13954: 1,
#           13694: 2,
#           13705: 1,
#           12959: 3,
#           13246: 16,
#           13832: 2,
#           13362: 1,
#           14073: 1,
#           13749: 5,
#           12883: 1,
#           12860: 1,
#           12861: 1,
#           12862: 1,
#           12998: 1,
#           12999: 1,
#           13238: 1,
#           13547: 1,
#           12731: 1,
#           12747: 1,
#           13742: 1,
#           13780: 3,
#           13716: 5,
#           13237: 6,
#           14091: 3,
#           12750: 3,
#           13767: 8,
#           13005: 3,
#           13757: 2,
#           12996: 1,
#           12997: 1,
#           12886: 1,
#           12956: 4,
#           13034: 7,
#           13048: 5,
#           13055: 1,
#           13243: 4,
#           12953: 7,
#           13049: 3,
#           13240: 7,
#           13063: 1,
#           13546: 1,
#           12919: 2,
#           13852: 1,
#           12848: 1,
#           13047: 1,
#           ...})}

# %%
# remove duplicate indexes

idx_iqr = list(set(idx_iqr))
for k, v in zip(idx_sds.keys(), idx_sds.values()):
    idx_sd[k] = list(set(idx_sd[k]))

# %% [markdown]
# ### try removing points X sds away from the mean and see results from t-tests

# %%
print(len(idx_iqr))
for i in sds:
    print(len(idx_sd[i]))
print(df.shape)
# Out:
# 64884
# 8882
# 5272
# (94370, 104)

# %%
df_sd_removed = {i:df.drop(idx_sd[i], axis=0) for i in sds}
df_iqr = df.drop(idx_iqr, axis=0)
print(df_iqr.shape[0])
for i in sds:
    print(df_sd_removed[i].shape[0])
# Out:
# 29486
# 85488
# 89098

# %%
# by plates
df_sd_removed_untr = {}
for k, v in zip(df_sd_removed.keys(), df_sd_removed.values()):
    tmp = pd.concat([v[v['Metadata_Metadata_Cytokine']=='untr'], v[v['Metadata_Metadata_Cytokine']=='untr-50']])
    df_sd_removed_untr[k] = tmp
# df_sd5_untr = pd.concat([df_sd5[df_sd5['Metadata_Metadata_Cytokine']=='untr'], df_sd5[df_sd5['Metadata_Metadata_Cytokine']=='untr-50']])
# df_sd6_untr = pd.concat([df_sd6[df_sd6['Metadata_Metadata_Cytokine']=='untr'], df_sd6[df_sd6['Metadata_Metadata_Cytokine']=='untr-50']])
df_iqr_untr = pd.concat([df_iqr[df_iqr['Metadata_Metadata_Cytokine']=='untr'], df_iqr[df_iqr['Metadata_Metadata_Cytokine']=='untr-50']])

print(df_iqr_untr.shape[0])
for i in sds:
    print(df_sd_removed_untr[i].shape[0])
# Out:
# 2885
# 8196
# 8503

# %%
feature = 'Granularity_1_CorrActin'

# %%
print('IQR')
print(eda.run_ANOVA_plates('untr', feature, df_iqr_untr))
print('5 sds')
print(eda.run_ANOVA_plates('untr', feature, df_sd_removed_untr[5]))
print('6 sds')
print(eda.run_ANOVA_plates('untr', feature, df_sd_removed_untr[6]))
# Out:
# IQR
# (  Cytokine                  Feature      F-stat        P-value
# 0     untr  Granularity_1_CorrActin  257.900013  6.447053e-102, 1.0)
# 5 sds
# (  Cytokine                  Feature      F-stat        P-value
# 0     untr  Granularity_1_CorrActin  443.984937  1.230771e-181, 1.0)
# 6 sds
# (  Cytokine                  Feature      F-stat        P-value
# 0     untr  Granularity_1_CorrActin  444.957925  2.089994e-182, 1.0)

# %%
# cannot run ANOVA on untr-50 since there is only one plate
df_iqr_untr[df_iqr_untr['Metadata_Metadata_Cytokine']=='untr-50']['Metadata_Plate'].unique()
# Out:
# array(['Plate 3'], dtype=object)

# %%
eda.plot_by_plate('untr', feature, df_iqr_untr)

# %%
eda.plot_by_plate('untr', feature, df_sd_removed_untr[5])

# %%
eda.plot_by_plate('untr', feature, df_sd_removed_untr[6])

# %%
# made slight changes to Matthew's plate_Tukey_HSD here

from statsmodels.stats.multicomp import pairwise_tukeyhsd
def plate_Tukey_HSD(untr, feature, df):
    untr_plates = df[(df['Metadata_Metadata_Cytokine'] == untr)]
    untr_plates = untr_plates[['Metadata_Plate', feature]]
    
    res = pairwise_tukeyhsd(endog=untr_plates[feature],
                          groups=untr_plates['Metadata_Plate'],
                          alpha=0.05)
    
    return res

print('IQR')
print(plate_Tukey_HSD('untr', feature, df_iqr_untr))
print('5 sds')
print(plate_Tukey_HSD('untr', feature, df_sd_removed_untr[5]))
print('6 sds')
print(plate_Tukey_HSD('untr', feature, df_sd_removed_untr[6]))
print('original df')
print(plate_Tukey_HSD('untr', feature, df))
# eda.plate_Tukey_HSD('untr', feature, df_sd5_untr)
# Out:
# IQR
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
# Plate 1 Plate 2  -1.3453 0.0037 -2.3256  -0.365   True
# Plate 1 Plate 3   8.4386    0.0  7.3656  9.5117   True
# Plate 2 Plate 3    9.784    0.0  8.7166 10.8513   True
# ------------------------------------------------------
# 5 sds
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj  lower   upper  reject
# -----------------------------------------------------
# Plate 1 Plate 2  -2.7005   0.0 -3.3921 -2.0088   True
# Plate 1 Plate 3   6.8119   0.0  6.0281  7.5958   True
# Plate 2 Plate 3   9.5124   0.0  8.7591 10.2657   True
# -----------------------------------------------------
# 6 sds
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj  lower   upper  reject
# -----------------------------------------------------
# Plate 1 Plate 2  -2.8281  -0.0 -3.5124 -2.1437   True
# Plate 1 Plate 3   6.5817  -0.0   5.808  7.3555   True
# Plate 2 Plate 3   9.4098  -0.0  8.6669 10.1527   True
# -----------------------------------------------------
# original df
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1  group2 meandiff p-adj  lower   upper  reject
# -----------------------------------------------------
# Plate 1 Plate 2  -2.7659   0.0 -3.4507 -2.0811   True
# Plate 1 Plate 3   6.4583   0.0  5.6857   7.231   True
# Plate 2 Plate 3   9.2242   0.0  8.4815  9.9669   True
# -----------------------------------------------------

# %%
# by wells
for i in cdw:
    if i[0]=='untr' or i[0]=='untr-50':
        continue
    print(eda.get_ttest_wells(i[0], feature, df_iqr))
# df_sd_removed_untr = {}
# for k, v in zip(df_sd_removed.keys(), df_sd_removed.values()):
#     tmp = pd.concat([v[v['Metadata_Metadata_Cytokine']=='untr'], v[v['Metadata_Metadata_Cytokine']=='untr-50']])
#     df_sd_removed_untr[k] = tmp
# df_iqr_untr = pd.concat([df_iqr[df_iqr['Metadata_Metadata_Cytokine']=='untr'], df_iqr[df_iqr['Metadata_Metadata_Cytokine']=='untr-50']])

# print(df_iqr_untr.shape[0])
# for i in sds:
#     print(df_sd_removed_untr[i].shape[0])
# Out:
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      EGF  Granularity_1_CorrActin        F2 vs G2        1.749    0.081
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      EGF  Granularity_1_CorrActin        F2 vs G2        1.749    0.081
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      EGF  Granularity_1_CorrActin        F2 vs G2        1.749    0.081
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      EGF  Granularity_1_CorrActin        F2 vs G2        1.749    0.081
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      EGF  Granularity_1_CorrActin        F2 vs G2        1.749    0.081
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      EGF  Granularity_1_CorrActin        F2 vs G2        1.749    0.081
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      FGF  Granularity_1_CorrActin        B2 vs C2       -5.608      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      FGF  Granularity_1_CorrActin        B2 vs C2       -5.608      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      FGF  Granularity_1_CorrActin        B2 vs C2       -5.608      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      FGF  Granularity_1_CorrActin        B2 vs C2       -5.608      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      FGF  Granularity_1_CorrActin        B2 vs C2       -5.608      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      FGF  Granularity_1_CorrActin        B2 vs C2       -5.608      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IFNg  Granularity_1_CorrActin        B9 vs C9        9.205      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IFNg  Granularity_1_CorrActin        B9 vs C9        9.205      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IFNg  Granularity_1_CorrActin        B9 vs C9        9.205      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IFNg  Granularity_1_CorrActin        B9 vs C9        9.205      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IFNg  Granularity_1_CorrActin        B9 vs C9        9.205      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IFNg  Granularity_1_CorrActin        B9 vs C9        9.205      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL13  Granularity_1_CorrActin        F2 vs G2        0.997    0.319
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL13  Granularity_1_CorrActin        F2 vs G2        0.997    0.319
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL13  Granularity_1_CorrActin        F2 vs G2        0.997    0.319
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL13  Granularity_1_CorrActin        F2 vs G2        0.997    0.319
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL13  Granularity_1_CorrActin        F2 vs G2        0.997    0.319
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL13  Granularity_1_CorrActin        F2 vs G2        0.997    0.319
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL17  Granularity_1_CorrActin        F9 vs G9        4.124      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL17  Granularity_1_CorrActin        F9 vs G9        4.124      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL17  Granularity_1_CorrActin        F9 vs G9        4.124      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL17  Granularity_1_CorrActin        F9 vs G9        4.124      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL17  Granularity_1_CorrActin        F9 vs G9        4.124      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL17  Granularity_1_CorrActin        F9 vs G9        4.124      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL22  Granularity_1_CorrActin        B2 vs C2       -2.509    0.012
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL22  Granularity_1_CorrActin        B2 vs C2       -2.509    0.012
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL22  Granularity_1_CorrActin        B2 vs C2       -2.509    0.012
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL22  Granularity_1_CorrActin        B2 vs C2       -2.509    0.012
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL22  Granularity_1_CorrActin        B2 vs C2       -2.509    0.012
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL22  Granularity_1_CorrActin        B2 vs C2       -2.509    0.012
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL26  Granularity_1_CorrActin        F2 vs G2        6.918      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL26  Granularity_1_CorrActin        F2 vs G2        6.918      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL26  Granularity_1_CorrActin        F2 vs G2        6.918      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL26  Granularity_1_CorrActin        F2 vs G2        6.918      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL26  Granularity_1_CorrActin        F2 vs G2        6.918      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     IL26  Granularity_1_CorrActin        F2 vs G2        6.918      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      IL9  Granularity_1_CorrActin        B9 vs C9       -6.711      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      IL9  Granularity_1_CorrActin        B9 vs C9       -6.711      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      IL9  Granularity_1_CorrActin        B9 vs C9       -6.711      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      IL9  Granularity_1_CorrActin        B9 vs C9       -6.711      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      IL9  Granularity_1_CorrActin        B9 vs C9       -6.711      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0      IL9  Granularity_1_CorrActin        B9 vs C9       -6.711      0.0
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TGFb  Granularity_1_CorrActin        B2 vs C2       -2.535    0.011
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TGFb  Granularity_1_CorrActin        B2 vs C2       -2.535    0.011
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TGFb  Granularity_1_CorrActin        B2 vs C2       -2.535    0.011
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TGFb  Granularity_1_CorrActin        B2 vs C2       -2.535    0.011
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TGFb  Granularity_1_CorrActin        B2 vs C2       -2.535    0.011
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TGFb  Granularity_1_CorrActin        B2 vs C2       -2.535    0.011
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TNFa  Granularity_1_CorrActin        F9 vs G9        0.148    0.882
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TNFa  Granularity_1_CorrActin        F9 vs G9        0.148    0.882
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TNFa  Granularity_1_CorrActin        F9 vs G9        0.148    0.882
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TNFa  Granularity_1_CorrActin        F9 vs G9        0.148    0.882
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TNFa  Granularity_1_CorrActin        F9 vs G9        0.148    0.882
#
#    Power
# 0    1.0
#   Cytokine                  Feature Well Comparison  T-Statistic  p-value  \
# 0     TNFa  Granularity_1_CorrActin        F9 vs G9        0.148    0.882
#
#    Power
# 0    1.0

# %% [markdown]
# ### add threshold to the last prompt by looking into out of all variables, in how many of those is a data point an outlier

# %% [markdown]
# ### look at different groups of variables or different signals (DNA/WGA/Mito/Golgi)

# %%
# features = df.columns[6:]
groups = ['Granularity', 'Intensity',
            'Texture_AngularSecondMoment', 
            'Texture_Contrast',
            'RadialDistribution_MeanFrac',
            'RadialDistribution_ZernikeMagnitude',
            'Area'
            ]
gran = df.filter(regex='Inten', axis=1).columns.tolist()
